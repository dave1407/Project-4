# %%
# Import dependencies
import sys
sys.path.append('./Resources')
import pymongo
import requests
import pandas as pd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
from census import Census

# Census API Key
from config import api_key
c = Census(api_key, year=2022)

# %% [markdown]
#    # Data pull and pre-processing

# %%
# Run Census Search to retrieve data on all county codes ( ACS5 Census)

def get_census(year):
    c = Census(api_key, year=year)
    census_data = c.acs5.get(("NAME", "B19013_001E", "B01003_001E", "B01002_001E",
                          "B19301_001E",
                          "B17001_002E"), 
                         {'for': 'county:*'})
                       

# Convert to DataFrame
    census_pd = pd.DataFrame(census_data)

# Column Reordering
    census_pd = census_pd.rename(columns={"B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B17001_002E": "Poverty Count",
                                      "NAME": "Name", "county": "County"
                                      })

# Add in Poverty Rate (Poverty Count / Population)
    census_pd["Poverty Rate"] = 100 * \
        census_pd["Poverty Count"].astype(
            int) / census_pd["Population"].astype(int)

# Final DataFrame
    census_pd = census_pd[["Name","County", "Population", "Median Age", "Household Income",
                           "Per Capita Income", "Poverty Count", "Poverty Rate"]]

    census_pd['county_name'] = census_pd['Name'].str.replace(r" County,(.*)",'').str.upper()
    census_pd['state'] = census_pd['Name'].str.replace(r"(.*) County, ",'').str.upper()

    
    return census_pd

census_2012 = get_census(2012)
census_2012.head()
census_2012['year'] = 2012

census_2016 = get_census(2016)
census_2016.head()
census_2016['year'] = 2016

census_2020 = get_census(2020)
census_2020['year'] = 2020
census_2020.head()

census = pd.concat([census_2012,census_2016,census_2020])
# Out:
# C:\Users\nico.cosereanu\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:32: FutureWarning: The default value of regex will change from True to False in a future version.
# C:\Users\nico.cosereanu\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:33: FutureWarning: The default value of regex will change from True to False in a future version.

# %%
census.dtypes
# Out:
# Name                  object
# County                object
# Population           float64
# Median Age           float64
# Household Income     float64
# Per Capita Income    float64
# Poverty Count        float64
# Poverty Rate         float64
# county_name           object
# state                 object
# year                   int64
# dtype: object

# %%
# Perform some data cleansing options Drop records with Household Income less then 0
census = census[census['Household Income']>0]
census
# Out:
#                              Name County  Population  Median Age  \
# 0           Linn County, Missouri    115     12668.0        43.0
# 1         Howell County, Missouri    091     40330.0        39.6
# 2        Johnson County, Missouri    101     52964.0        29.7
# 3        Laclede County, Missouri    105     35507.0        39.1
# 4         Maries County, Missouri    125      9140.0        43.1
# ...                           ...    ...         ...         ...
# 3216   Renville County, Minnesota    129     14572.0        44.0
# 3217     Roseau County, Minnesota    135     15259.0        41.6
# 3218  Sherburne County, Minnesota    141     96015.0        36.1
# 3219     Steele County, Minnesota    147     36710.0        39.2
# 3220       Todd County, Minnesota    153     24603.0        43.9
#
#       Household Income  Per Capita Income  Poverty Count  Poverty Rate  \
# 0              39028.0            20968.0         1678.0     13.245974
# 1              34148.0            17763.0         8187.0     20.300025
# 2              47960.0            21375.0         8075.0     15.246205
# 3              39101.0            19788.0         6478.0     18.244290
# 4              44885.0            21883.0         1286.0     14.070022
# ...                ...                ...            ...           ...
# 3216           58542.0            31243.0         1373.0      9.422180
# 3217           62304.0            31452.0         1133.0      7.425126
# 3218           88671.0            36022.0         4953.0      5.158569
# 3219           68172.0            34648.0         2887.0      7.864342
# 3220           54502.0            26427.0         3276.0     13.315449
#
#      county_name      state  year
# 0           LINN   MISSOURI  2012
# 1         HOWELL   MISSOURI  2012
# 2        JOHNSON   MISSOURI  2012
# 3        LACLEDE   MISSOURI  2012
# 4         MARIES   MISSOURI  2012
# ...          ...        ...   ...
# 3216    RENVILLE  MINNESOTA  2020
# 3217      ROSEAU  MINNESOTA  2020
# 3218   SHERBURNE  MINNESOTA  2020
# 3219      STEELE  MINNESOTA  2020
# 3220        TODD  MINNESOTA  2020
#
# [9661 rows x 11 columns]

# %%
# Import the winner values by county
winners_pd=pd.read_csv("Resources/countypres_2000-2020_with_winner.csv")
winners_pd
# Out:
#        year    state state_po county_name  county_fips        office  \
# 0      2000  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 1      2000  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 2      2000  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 3      2000  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 4      2000  ALABAMA       AL     BALDWIN       1003.0  US PRESIDENT
# ...     ...      ...      ...         ...          ...           ...
# 72612  2020  WYOMING       WY    WASHAKIE      56043.0  US PRESIDENT
# 72613  2020  WYOMING       WY      WESTON      56045.0  US PRESIDENT
# 72614  2020  WYOMING       WY      WESTON      56045.0  US PRESIDENT
# 72615  2020  WYOMING       WY      WESTON      56045.0  US PRESIDENT
# 72616  2020  WYOMING       WY      WESTON      56045.0  US PRESIDENT
#
#                candidate        party  candidatevotes  totalvotes   version  \
# 0                AL GORE     DEMOCRAT            4942       17208  20220315
# 1         GEORGE W. BUSH   REPUBLICAN           11993       17208  20220315
# 2            RALPH NADER        GREEN             160       17208  20220315
# 3                  OTHER        OTHER             113       17208  20220315
# 4                AL GORE     DEMOCRAT           13997       56480  20220315
# ...                  ...          ...             ...         ...       ...
# 72612     DONALD J TRUMP   REPUBLICAN            3245        4032  20220315
# 72613  JOSEPH R BIDEN JR     DEMOCRAT             360        3560  20220315
# 72614       JO JORGENSEN  LIBERTARIAN              46        3560  20220315
# 72615              OTHER        OTHER              47        3560  20220315
# 72616     DONALD J TRUMP   REPUBLICAN            3107        3560  20220315
#
#         mode               Concat      Winner
# 0      TOTAL   2000ALABAMAAUTAUGA  Republican
# 1      TOTAL   2000ALABAMAAUTAUGA  Republican
# 2      TOTAL   2000ALABAMAAUTAUGA  Republican
# 3      TOTAL   2000ALABAMAAUTAUGA  Republican
# 4      TOTAL   2000ALABAMABALDWIN  Republican
# ...      ...                  ...         ...
# 72612  TOTAL  2020WYOMINGWASHAKIE  Republican
# 72613  TOTAL    2020WYOMINGWESTON  Republican
# 72614  TOTAL    2020WYOMINGWESTON  Republican
# 72615  TOTAL    2020WYOMINGWESTON  Republican
# 72616  TOTAL    2020WYOMINGWESTON  Republican
#
# [72617 rows x 14 columns]

# %%
winners_pd = winners_pd[((winners_pd['year'] == 2012) | (winners_pd['year'] == 2016) | (winners_pd['year'] == 2020))]
winners_pd = winners_pd[((winners_pd['party'] == 'DEMOCRAT') | (winners_pd['party'] == 'REPUBLICAN'))]
winners_pd=winners_pd.drop_duplicates(subset=['state_po','county_name', 'year'],keep='first')

# %%
winners_pd
# Out:
#        year    state state_po county_name  county_fips        office  \
# 31166  2012  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 31169  2012  ALABAMA       AL     BALDWIN       1003.0  US PRESIDENT
# 31172  2012  ALABAMA       AL     BARBOUR       1005.0  US PRESIDENT
# 31175  2012  ALABAMA       AL        BIBB       1007.0  US PRESIDENT
# 31178  2012  ALABAMA       AL      BLOUNT       1009.0  US PRESIDENT
# ...     ...      ...      ...         ...          ...           ...
# 72597  2020  WYOMING       WY  SWEETWATER      56037.0  US PRESIDENT
# 72601  2020  WYOMING       WY       TETON      56039.0  US PRESIDENT
# 72605  2020  WYOMING       WY       UINTA      56041.0  US PRESIDENT
# 72609  2020  WYOMING       WY    WASHAKIE      56043.0  US PRESIDENT
# 72613  2020  WYOMING       WY      WESTON      56045.0  US PRESIDENT
#
#                candidate     party  candidatevotes  totalvotes   version  \
# 31166       BARACK OBAMA  DEMOCRAT            6363       23932  20220315
# 31169       BARACK OBAMA  DEMOCRAT           18424       85338  20220315
# 31172       BARACK OBAMA  DEMOCRAT            5912       11509  20220315
# 31175       BARACK OBAMA  DEMOCRAT            2202        8420  20220315
# 31178       BARACK OBAMA  DEMOCRAT            2970       24006  20220315
# ...                  ...       ...             ...         ...       ...
# 72597  JOSEPH R BIDEN JR  DEMOCRAT            3823       16698  20220315
# 72601  JOSEPH R BIDEN JR  DEMOCRAT            9848       14787  20220315
# 72605  JOSEPH R BIDEN JR  DEMOCRAT            1591        9459  20220315
# 72609  JOSEPH R BIDEN JR  DEMOCRAT             651        4032  20220315
# 72613  JOSEPH R BIDEN JR  DEMOCRAT             360        3560  20220315
#
#         mode                 Concat      Winner
# 31166  TOTAL     2012ALABAMAAUTAUGA  Republican
# 31169  TOTAL     2012ALABAMABALDWIN  Republican
# 31172  TOTAL     2012ALABAMABARBOUR    Democrat
# 31175  TOTAL        2012ALABAMABIBB  Republican
# 31178  TOTAL      2012ALABAMABLOUNT  Republican
# ...      ...                    ...         ...
# 72597  TOTAL  2020WYOMINGSWEETWATER  Republican
# 72601  TOTAL       2020WYOMINGTETON    Democrat
# 72605  TOTAL       2020WYOMINGUINTA  Republican
# 72609  TOTAL    2020WYOMINGWASHAKIE  Republican
# 72613  TOTAL      2020WYOMINGWESTON  Republican
#
# [9461 rows x 14 columns]

# %%
# Merge the winner info with the previosuly established DF
cleaned_census_data = pd.merge(census, winners_pd, how='left', left_on=['year','state', 'county_name'], right_on=['year','state', 'county_name'])

cleaned_census_data = cleaned_census_data[['year','state','state_po','county_name','Population','Median Age', 'Household Income', 'Per Capita Income', 'Poverty Rate', 'Winner']]
cleaned_census_data
# Out:
#       year      state state_po county_name  Population  Median Age  \
# 0     2012   MISSOURI       MO        LINN     12668.0        43.0
# 1     2012   MISSOURI       MO      HOWELL     40330.0        39.6
# 2     2012   MISSOURI       MO     JOHNSON     52964.0        29.7
# 3     2012   MISSOURI       MO     LACLEDE     35507.0        39.1
# 4     2012   MISSOURI       MO      MARIES      9140.0        43.1
# ...    ...        ...      ...         ...         ...         ...
# 9656  2020  MINNESOTA       MN    RENVILLE     14572.0        44.0
# 9657  2020  MINNESOTA       MN      ROSEAU     15259.0        41.6
# 9658  2020  MINNESOTA       MN   SHERBURNE     96015.0        36.1
# 9659  2020  MINNESOTA       MN      STEELE     36710.0        39.2
# 9660  2020  MINNESOTA       MN        TODD     24603.0        43.9
#
#       Household Income  Per Capita Income  Poverty Rate      Winner
# 0              39028.0            20968.0     13.245974  Republican
# 1              34148.0            17763.0     20.300025  Republican
# 2              47960.0            21375.0     15.246205  Republican
# 3              39101.0            19788.0     18.244290  Republican
# 4              44885.0            21883.0     14.070022  Republican
# ...                ...                ...           ...         ...
# 9656           58542.0            31243.0      9.422180  Republican
# 9657           62304.0            31452.0      7.425126  Republican
# 9658           88671.0            36022.0      5.158569  Republican
# 9659           68172.0            34648.0      7.864342  Republican
# 9660           54502.0            26427.0     13.315449  Republican
#
# [9661 rows x 10 columns]

# %%
cleaned_census_data.dropna(subset =["state_po"],inplace=True)

# %%
# Create the final dataset for ML application
db_data = cleaned_census_data
db_data
# Out:
#       year      state state_po county_name  Population  Median Age  \
# 0     2012   MISSOURI       MO        LINN     12668.0        43.0
# 1     2012   MISSOURI       MO      HOWELL     40330.0        39.6
# 2     2012   MISSOURI       MO     JOHNSON     52964.0        29.7
# 3     2012   MISSOURI       MO     LACLEDE     35507.0        39.1
# 4     2012   MISSOURI       MO      MARIES      9140.0        43.1
# ...    ...        ...      ...         ...         ...         ...
# 9656  2020  MINNESOTA       MN    RENVILLE     14572.0        44.0
# 9657  2020  MINNESOTA       MN      ROSEAU     15259.0        41.6
# 9658  2020  MINNESOTA       MN   SHERBURNE     96015.0        36.1
# 9659  2020  MINNESOTA       MN      STEELE     36710.0        39.2
# 9660  2020  MINNESOTA       MN        TODD     24603.0        43.9
#
#       Household Income  Per Capita Income  Poverty Rate      Winner
# 0              39028.0            20968.0     13.245974  Republican
# 1              34148.0            17763.0     20.300025  Republican
# 2              47960.0            21375.0     15.246205  Republican
# 3              39101.0            19788.0     18.244290  Republican
# 4              44885.0            21883.0     14.070022  Republican
# ...                ...                ...           ...         ...
# 9656           58542.0            31243.0      9.422180  Republican
# 9657           62304.0            31452.0      7.425126  Republican
# 9658           88671.0            36022.0      5.158569  Republican
# 9659           68172.0            34648.0      7.864342  Republican
# 9660           54502.0            26427.0     13.315449  Republican
#
# [9007 rows x 10 columns]

# %%
#Uploading The Pandas DataFrame to MongoDB
# Convert dataframe to dictinary
db_data_ML=db_data.to_dict("records")
db_data_ML
# Out:
# [{'year': 2012,
#   'state': 'MISSOURI',
#   'state_po': 'MO',
#   'county_name': 'LINN',
#   'Population': 12668.0,
#   'Median Age': 43.0,
#   'Household Income': 39028.0,
#   'Per Capita Income': 20968.0,
#   'Poverty Rate': 13.245974107988634,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSOURI',
#   'state_po': 'MO',
#   'county_name': 'HOWELL',
#   'Population': 40330.0,
#   'Median Age': 39.6,
#   'Household Income': 34148.0,
#   'Per Capita Income': 17763.0,
#   'Poverty Rate': 20.30002479543764,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSOURI',
#   'state_po': 'MO',
#   'county_name': 'JOHNSON',
#   'Population': 52964.0,
#   'Median Age': 29.7,
#   'Household Income': 47960.0,
#   'Per Capita Income': 21375.0,
#   'Poverty Rate': 15.246204969413187,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSOURI',
#   'state_po': 'MO',
#   'county_name': 'LACLEDE',
#   'Population': 35507.0,
#   'Median Age': 39.1,
#   'Household Income': 39101.0,
#   'Per Capita Income': 19788.0,
#   'Poverty Rate': 18.244289858337794,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSOURI',
#   'state_po': 'MO',
#   'county_name': 'MARIES',
#   'Population': 9140.0,
#   'Median Age': 43.1,
#   'Household Income': 44885.0,
#   'Per Capita Income': 21883.0,
#   'Poverty Rate': 14.070021881838075,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSOURI',
#   'state_po': 'MO',
#   'county_name': 'PHELPS',
#   'Population': 44825.0,
#   'Median Age': 34.0,
#   'Household Income': 41388.0,
#   'Per Capita Income': 20319.0,
#   'Poverty Rate': 17.46793084216397,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSOURI',
#   'state_po': 'MO',
#   'county_name': 'PLATTE',
#   'Population': 89567.0,
#   'Median Age': 38.5,
#   'Household Income': 67419.0,
#   'Per Capita Income': 35133.0,
#   'Poverty Rate': 7.254904149965947,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSOURI',
#   'state_po': 'MO',
#   'county_name': 'ST. FRANCOIS',
#   'Population': 65246.0,
#   'Median Age': 38.7,
#   'Household Income': 36716.0,
#   'Per Capita Income': 18893.0,
#   'Poverty Rate': 16.066885326303527,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSOURI',
#   'state_po': 'MO',
#   'county_name': 'ANDREW',
#   'Population': 17205.0,
#   'Median Age': 41.9,
#   'Household Income': 57406.0,
#   'Per Capita Income': 25821.0,
#   'Poverty Rate': 7.265329845975007,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSOURI',
#   'state_po': 'MO',
#   'county_name': 'BUTLER',
#   'Population': 42792.0,
#   'Median Age': 40.6,
#   'Household Income': 34343.0,
#   'Per Capita Income': 19775.0,
#   'Poverty Rate': 19.971022621050665,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSOURI',
#   'state_po': 'MO',
#   'county_name': 'CARROLL',
#   'Population': 9279.0,
#   'Median Age': 41.8,
#   'Household Income': 44858.0,
#   'Per Capita Income': 25174.0,
#   'Poverty Rate': 12.856988899665913,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSOURI',
#   'state_po': 'MO',
#   'county_name': 'DAVIESS',
#   'Population': 8341.0,
#   'Median Age': 40.3,
#   'Household Income': 42617.0,
#   'Per Capita Income': 20364.0,
#   'Poverty Rate': 14.039084042680734,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSOURI',
#   'state_po': 'MO',
#   'county_name': 'HOLT',
#   'Population': 4840.0,
#   'Median Age': 46.1,
#   'Household Income': 42706.0,
#   'Per Capita Income': 23943.0,
#   'Poverty Rate': 14.173553719008265,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSOURI',
#   'state_po': 'MO',
#   'county_name': 'MARION',
#   'Population': 28703.0,
#   'Median Age': 39.3,
#   'Household Income': 42756.0,
#   'Per Capita Income': 22168.0,
#   'Poverty Rate': 14.657004494303731,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSOURI',
#   'state_po': 'MO',
#   'county_name': 'OSAGE',
#   'Population': 13857.0,
#   'Median Age': 39.2,
#   'Household Income': 51006.0,
#   'Per Capita Income': 22253.0,
#   'Poverty Rate': 9.79288446272642,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSOURI',
#   'state_po': 'MO',
#   'county_name': 'RIPLEY',
#   'Population': 14070.0,
#   'Median Age': 41.9,
#   'Household Income': 31431.0,
#   'Per Capita Income': 15367.0,
#   'Poverty Rate': 26.986496090973702,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSOURI',
#   'state_po': 'MO',
#   'county_name': 'WARREN',
#   'Population': 32440.0,
#   'Median Age': 39.7,
#   'Household Income': 47877.0,
#   'Per Capita Income': 24581.0,
#   'Poverty Rate': 14.204685573366215,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSOURI',
#   'state_po': 'MO',
#   'county_name': 'WASHINGTON',
#   'Population': 25120.0,
#   'Median Age': 40.1,
#   'Household Income': 34015.0,
#   'Per Capita Income': 18010.0,
#   'Poverty Rate': 22.60748407643312,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSOURI',
#   'state_po': 'MO',
#   'county_name': 'CHRISTIAN',
#   'Population': 77474.0,
#   'Median Age': 36.7,
#   'Household Income': 53549.0,
#   'Per Capita Income': 24879.0,
#   'Poverty Rate': 9.976250096806671,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSOURI',
#   'state_po': 'MO',
#   'county_name': 'DEKALB',
#   'Population': 12878.0,
#   'Median Age': 40.2,
#   'Household Income': 43898.0,
#   'Per Capita Income': 16729.0,
#   'Poverty Rate': 6.111197390899208,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSOURI',
#   'state_po': 'MO',
#   'county_name': 'HARRISON',
#   'Population': 8901.0,
#   'Median Age': 42.6,
#   'Household Income': 36909.0,
#   'Per Capita Income': 19706.0,
#   'Poverty Rate': 13.751263902932255,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSOURI',
#   'state_po': 'MO',
#   'county_name': 'LAFAYETTE',
#   'Population': 33278.0,
#   'Median Age': 40.3,
#   'Household Income': 51917.0,
#   'Per Capita Income': 23679.0,
#   'Poverty Rate': 9.820301700823366,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSOURI',
#   'state_po': 'MO',
#   'county_name': 'ADAIR',
#   'Population': 25542.0,
#   'Median Age': 29.1,
#   'Household Income': 33284.0,
#   'Per Capita Income': 18331.0,
#   'Poverty Rate': 21.44311330357842,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSOURI',
#   'state_po': 'MO',
#   'county_name': 'SCOTLAND',
#   'Population': 4843.0,
#   'Median Age': 39.4,
#   'Household Income': 40017.0,
#   'Per Capita Income': 20305.0,
#   'Poverty Rate': 18.21185215775346,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSOURI',
#   'state_po': 'MO',
#   'county_name': 'SULLIVAN',
#   'Population': 6667.0,
#   'Median Age': 40.2,
#   'Household Income': 34247.0,
#   'Per Capita Income': 18348.0,
#   'Poverty Rate': 17.27913604319784,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSOURI',
#   'state_po': 'MO',
#   'county_name': 'CLARK',
#   'Population': 7082.0,
#   'Median Age': 43.1,
#   'Household Income': 40466.0,
#   'Per Capita Income': 19898.0,
#   'Poverty Rate': 16.26659135837334,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSOURI',
#   'state_po': 'MO',
#   'county_name': 'JASPER',
#   'Population': 116493.0,
#   'Median Age': 35.1,
#   'Household Income': 39908.0,
#   'Per Capita Income': 20801.0,
#   'Poverty Rate': 18.45690298987922,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSOURI',
#   'state_po': 'MO',
#   'county_name': 'LEWIS',
#   'Population': 10203.0,
#   'Median Age': 38.7,
#   'Household Income': 41758.0,
#   'Per Capita Income': 19230.0,
#   'Poverty Rate': 14.113496030579242,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSOURI',
#   'state_po': 'MO',
#   'county_name': 'MCDONALD',
#   'Population': 22970.0,
#   'Median Age': 36.5,
#   'Household Income': 36719.0,
#   'Per Capita Income': 17429.0,
#   'Poverty Rate': 21.619503700478887,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSOURI',
#   'state_po': 'MO',
#   'county_name': 'PERRY',
#   'Population': 18986.0,
#   'Median Age': 39.5,
#   'Household Income': 45553.0,
#   'Per Capita Income': 23084.0,
#   'Poverty Rate': 12.219530180132729,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSOURI',
#   'state_po': 'MO',
#   'county_name': 'POLK',
#   'Population': 31035.0,
#   'Median Age': 38.1,
#   'Household Income': 38852.0,
#   'Per Capita Income': 18876.0,
#   'Poverty Rate': 21.57241823747382,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSOURI',
#   'state_po': 'MO',
#   'county_name': 'RAY',
#   'Population': 23422.0,
#   'Median Age': 40.0,
#   'Household Income': 52656.0,
#   'Per Capita Income': 24157.0,
#   'Poverty Rate': 10.255315515327469,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MONTANA',
#   'state_po': 'MT',
#   'county_name': 'HILL',
#   'Population': 16157.0,
#   'Median Age': 35.2,
#   'Household Income': 42875.0,
#   'Per Capita Income': 21753.0,
#   'Poverty Rate': 17.800334220461718,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'MONTANA',
#   'state_po': 'MT',
#   'county_name': 'CHOUTEAU',
#   'Population': 5811.0,
#   'Median Age': 41.5,
#   'Household Income': 41232.0,
#   'Per Capita Income': 21656.0,
#   'Poverty Rate': 18.241266563414214,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MONTANA',
#   'state_po': 'MT',
#   'county_name': 'LINCOLN',
#   'Population': 19594.0,
#   'Median Age': 49.2,
#   'Household Income': 33234.0,
#   'Per Capita Income': 21669.0,
#   'Poverty Rate': 20.189854036950088,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MONTANA',
#   'state_po': 'MT',
#   'county_name': 'PARK',
#   'Population': 15655.0,
#   'Median Age': 45.9,
#   'Household Income': 40781.0,
#   'Per Capita Income': 24126.0,
#   'Poverty Rate': 10.865538166719897,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MONTANA',
#   'state_po': 'MT',
#   'county_name': 'TREASURE',
#   'Population': 698.0,
#   'Median Age': 51.9,
#   'Household Income': 38125.0,
#   'Per Capita Income': 24537.0,
#   'Poverty Rate': 11.318051575931232,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MONTANA',
#   'state_po': 'MT',
#   'county_name': 'BLAINE',
#   'Population': 6514.0,
#   'Median Age': 35.0,
#   'Household Income': 37899.0,
#   'Per Capita Income': 17250.0,
#   'Poverty Rate': 26.71169788148603,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'MONTANA',
#   'state_po': 'MT',
#   'county_name': 'SWEET GRASS',
#   'Population': 3661.0,
#   'Median Age': 43.1,
#   'Household Income': 44179.0,
#   'Per Capita Income': 20927.0,
#   'Poverty Rate': 11.526905217153782,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MONTANA',
#   'state_po': 'MT',
#   'county_name': 'TETON',
#   'Population': 6082.0,
#   'Median Age': 45.6,
#   'Household Income': 42423.0,
#   'Per Capita Income': 22341.0,
#   'Poverty Rate': 13.54817494245314,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MONTANA',
#   'state_po': 'MT',
#   'county_name': 'PRAIRIE',
#   'Population': 1193.0,
#   'Median Age': 56.3,
#   'Household Income': 34875.0,
#   'Per Capita Income': 19677.0,
#   'Poverty Rate': 18.860016764459345,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MONTANA',
#   'state_po': 'MT',
#   'county_name': 'GLACIER',
#   'Population': 13422.0,
#   'Median Age': 31.4,
#   'Household Income': 36872.0,
#   'Per Capita Income': 17247.0,
#   'Poverty Rate': 28.565042467590523,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'MONTANA',
#   'state_po': 'MT',
#   'county_name': 'FALLON',
#   'Population': 3051.0,
#   'Median Age': 40.8,
#   'Household Income': 49732.0,
#   'Per Capita Income': 28047.0,
#   'Poverty Rate': 8.58734841035726,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MONTANA',
#   'state_po': 'MT',
#   'county_name': 'GOLDEN VALLEY',
#   'Population': 769.0,
#   'Median Age': 50.2,
#   'Household Income': 38289.0,
#   'Per Capita Income': 20696.0,
#   'Poverty Rate': 22.886866059817944,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MONTANA',
#   'state_po': 'MT',
#   'county_name': 'SILVER BOW',
#   'Population': 34164.0,
#   'Median Age': 41.7,
#   'Household Income': 39211.0,
#   'Per Capita Income': 22770.0,
#   'Poverty Rate': 16.669593724388246,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'MONTANA',
#   'state_po': 'MT',
#   'county_name': 'STILLWATER',
#   'Population': 9096.0,
#   'Median Age': 46.0,
#   'Household Income': 53533.0,
#   'Per Capita Income': 27824.0,
#   'Poverty Rate': 9.355760773966578,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MONTANA',
#   'state_po': 'MT',
#   'county_name': 'JEFFERSON',
#   'Population': 11360.0,
#   'Median Age': 46.8,
#   'Household Income': 60459.0,
#   'Per Capita Income': 29875.0,
#   'Poverty Rate': 7.649647887323944,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MONTANA',
#   'state_po': 'MT',
#   'county_name': 'GRANITE',
#   'Population': 3083.0,
#   'Median Age': 51.8,
#   'Household Income': 40511.0,
#   'Per Capita Income': 26018.0,
#   'Poverty Rate': 13.396042815439507,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MONTANA',
#   'state_po': 'MT',
#   'county_name': 'WHEATLAND',
#   'Population': 2142.0,
#   'Median Age': 48.5,
#   'Household Income': 31496.0,
#   'Per Capita Income': 17243.0,
#   'Poverty Rate': 12.511671335200747,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MONTANA',
#   'state_po': 'MT',
#   'county_name': 'MADISON',
#   'Population': 7688.0,
#   'Median Age': 50.0,
#   'Household Income': 48600.0,
#   'Per Capita Income': 32711.0,
#   'Poverty Rate': 10.626951092611863,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MONTANA',
#   'state_po': 'MT',
#   'county_name': 'SHERIDAN',
#   'Population': 3447.0,
#   'Median Age': 48.2,
#   'Household Income': 48148.0,
#   'Per Capita Income': 29569.0,
#   'Poverty Rate': 9.747606614447346,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MONTANA',
#   'state_po': 'MT',
#   'county_name': 'CARTER',
#   'Population': 1276.0,
#   'Median Age': 51.5,
#   'Household Income': 38750.0,
#   'Per Capita Income': 22095.0,
#   'Poverty Rate': 13.871473354231975,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MONTANA',
#   'state_po': 'MT',
#   'county_name': 'BIG HORN',
#   'Population': 12872.0,
#   'Median Age': 30.1,
#   'Household Income': 36803.0,
#   'Per Capita Income': 15239.0,
#   'Poverty Rate': 26.25077688004972,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'MONTANA',
#   'state_po': 'MT',
#   'county_name': 'LAKE',
#   'Population': 28794.0,
#   'Median Age': 41.0,
#   'Household Income': 37211.0,
#   'Per Capita Income': 20604.0,
#   'Poverty Rate': 22.845037160519553,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MONTANA',
#   'state_po': 'MT',
#   'county_name': 'LEWIS AND CLARK',
#   'Population': 63432.0,
#   'Median Age': 40.7,
#   'Household Income': 54535.0,
#   'Per Capita Income': 27861.0,
#   'Poverty Rate': 9.460524656324884,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MONTANA',
#   'state_po': 'MT',
#   'county_name': 'PONDERA',
#   'Population': 6147.0,
#   'Median Age': 42.9,
#   'Household Income': 39223.0,
#   'Per Capita Income': 22391.0,
#   'Poverty Rate': 17.927444281763464,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MONTANA',
#   'state_po': 'MT',
#   'county_name': 'YELLOWSTONE',
#   'Population': 148191.0,
#   'Median Age': 38.5,
#   'Household Income': 50608.0,
#   'Per Capita Income': 27607.0,
#   'Poverty Rate': 11.674798064659797,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MONTANA',
#   'state_po': 'MT',
#   'county_name': 'MISSOULA',
#   'Population': 109402.0,
#   'Median Age': 34.3,
#   'Household Income': 44653.0,
#   'Per Capita Income': 25548.0,
#   'Poverty Rate': 16.41103453318952,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'WISCONSIN',
#   'state_po': 'WI',
#   'county_name': 'BARRON',
#   'Population': 45882.0,
#   'Median Age': 42.7,
#   'Household Income': 44149.0,
#   'Per Capita Income': 23029.0,
#   'Poverty Rate': 12.619327840983392,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'WISCONSIN',
#   'state_po': 'WI',
#   'county_name': 'SAWYER',
#   'Population': 16580.0,
#   'Median Age': 47.2,
#   'Household Income': 39814.0,
#   'Per Capita Income': 23213.0,
#   'Poverty Rate': 19.11338962605549,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'WISCONSIN',
#   'state_po': 'WI',
#   'county_name': 'GREEN LAKE',
#   'Population': 19064.0,
#   'Median Age': 44.4,
#   'Household Income': 48772.0,
#   'Per Capita Income': 25997.0,
#   'Poverty Rate': 10.081829626521191,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'WISCONSIN',
#   'state_po': 'WI',
#   'county_name': 'PRICE',
#   'Population': 14141.0,
#   'Median Age': 48.8,
#   'Household Income': 42206.0,
#   'Per Capita Income': 23925.0,
#   'Poverty Rate': 13.86747754755675,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'WISCONSIN',
#   'state_po': 'WI',
#   'county_name': 'MARQUETTE',
#   'Population': 15366.0,
#   'Median Age': 47.2,
#   'Household Income': 44879.0,
#   'Per Capita Income': 23004.0,
#   'Poverty Rate': 13.673044383704282,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'WISCONSIN',
#   'state_po': 'WI',
#   'county_name': 'MARINETTE',
#   'Population': 41704.0,
#   'Median Age': 45.8,
#   'Household Income': 41533.0,
#   'Per Capita Income': 23689.0,
#   'Poverty Rate': 12.682236715902551,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'WISCONSIN',
#   'state_po': 'WI',
#   'county_name': 'MILWAUKEE',
#   'Population': 946584.0,
#   'Median Age': 33.7,
#   'Household Income': 43599.0,
#   'Per Capita Income': 24254.0,
#   'Poverty Rate': 20.396499412624763,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'WISCONSIN',
#   'state_po': 'WI',
#   'county_name': 'RACINE',
#   'Population': 195024.0,
#   'Median Age': 39.0,
#   'Household Income': 54900.0,
#   'Per Capita Income': 27292.0,
#   'Poverty Rate': 12.250799901550579,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'WISCONSIN',
#   'state_po': 'WI',
#   'county_name': 'DUNN',
#   'Population': 43788.0,
#   'Median Age': 33.6,
#   'Household Income': 47847.0,
#   'Per Capita Income': 22242.0,
#   'Poverty Rate': 15.040650406504065,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'WISCONSIN',
#   'state_po': 'WI',
#   'county_name': 'FOREST',
#   'Population': 9361.0,
#   'Median Age': 44.0,
#   'Household Income': 40215.0,
#   'Per Capita Income': 20684.0,
#   'Poverty Rate': 15.564576434141651,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'WISCONSIN',
#   'state_po': 'WI',
#   'county_name': 'GRANT',
#   'Population': 51055.0,
#   'Median Age': 36.5,
#   'Household Income': 46138.0,
#   'Per Capita Income': 21391.0,
#   'Poverty Rate': 14.378611301537557,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'WISCONSIN',
#   'state_po': 'WI',
#   'county_name': 'RUSK',
#   'Population': 14670.0,
#   'Median Age': 46.1,
#   'Household Income': 38629.0,
#   'Per Capita Income': 21292.0,
#   'Poverty Rate': 17.246080436264485,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'WISCONSIN',
#   'state_po': 'WI',
#   'county_name': 'SHEBOYGAN',
#   'Population': 115377.0,
#   'Median Age': 40.2,
#   'Household Income': 52967.0,
#   'Per Capita Income': 25793.0,
#   'Poverty Rate': 8.498227549684946,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'WISCONSIN',
#   'state_po': 'WI',
#   'county_name': 'MENOMINEE',
#   'Population': 4274.0,
#   'Median Age': 32.6,
#   'Household Income': 37644.0,
#   'Per Capita Income': 14479.0,
#   'Poverty Rate': 22.882545624707532,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'WISCONSIN',
#   'state_po': 'WI',
#   'county_name': 'OUTAGAMIE',
#   'Population': 176777.0,
#   'Median Age': 37.3,
#   'Household Income': 57584.0,
#   'Per Capita Income': 28185.0,
#   'Poverty Rate': 8.48356969515265,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'WISCONSIN',
#   'state_po': 'WI',
#   'county_name': 'BUFFALO',
#   'Population': 13544.0,
#   'Median Age': 44.0,
#   'Household Income': 47119.0,
#   'Per Capita Income': 23913.0,
#   'Poverty Rate': 11.200531600708802,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'WISCONSIN',
#   'state_po': 'WI',
#   'county_name': 'COLUMBIA',
#   'Population': 56596.0,
#   'Median Age': 41.3,
#   'Household Income': 57869.0,
#   'Per Capita Income': 28017.0,
#   'Poverty Rate': 8.749734963601668,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'WISCONSIN',
#   'state_po': 'WI',
#   'county_name': 'LA CROSSE',
#   'Population': 114718.0,
#   'Median Age': 35.3,
#   'Household Income': 50771.0,
#   'Per Capita Income': 25978.0,
#   'Poverty Rate': 13.119998605275546,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'WISCONSIN',
#   'state_po': 'WI',
#   'county_name': 'BROWN',
#   'Population': 248526.0,
#   'Median Age': 36.2,
#   'Household Income': 53419.0,
#   'Per Capita Income': 27862.0,
#   'Poverty Rate': 10.599695806474976,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'WISCONSIN',
#   'state_po': 'WI',
#   'county_name': 'MARATHON',
#   'Population': 134041.0,
#   'Median Age': 39.2,
#   'Household Income': 53762.0,
#   'Per Capita Income': 27173.0,
#   'Poverty Rate': 10.215531068852068,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'WISCONSIN',
#   'state_po': 'WI',
#   'county_name': 'ONEIDA',
#   'Population': 36029.0,
#   'Median Age': 48.2,
#   'Household Income': 44181.0,
#   'Per Capita Income': 26374.0,
#   'Poverty Rate': 10.547059313330928,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'WISCONSIN',
#   'state_po': 'WI',
#   'county_name': 'TREMPEALEAU',
#   'Population': 28853.0,
#   'Median Age': 40.9,
#   'Household Income': 48624.0,
#   'Per Capita Income': 24278.0,
#   'Poverty Rate': 11.721484767615152,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'WISCONSIN',
#   'state_po': 'WI',
#   'county_name': 'WAUKESHA',
#   'Population': 389740.0,
#   'Median Age': 42.2,
#   'Household Income': 75689.0,
#   'Per Capita Income': 37282.0,
#   'Poverty Rate': 4.912249191768872,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'WISCONSIN',
#   'state_po': 'WI',
#   'county_name': 'DODGE',
#   'Population': 88741.0,
#   'Median Age': 40.6,
#   'Household Income': 53782.0,
#   'Per Capita Income': 24907.0,
#   'Poverty Rate': 7.7855782558231255,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'WISCONSIN',
#   'state_po': 'WI',
#   'county_name': 'VILAS',
#   'Population': 21489.0,
#   'Median Age': 50.9,
#   'Household Income': 40743.0,
#   'Per Capita Income': 26423.0,
#   'Poverty Rate': 13.834985341337429,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'WISCONSIN',
#   'state_po': 'WI',
#   'county_name': 'CRAWFORD',
#   'Population': 16677.0,
#   'Median Age': 44.5,
#   'Household Income': 41743.0,
#   'Per Capita Income': 22331.0,
#   'Poverty Rate': 11.746717035438028,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'WISCONSIN',
#   'state_po': 'WI',
#   'county_name': 'MANITOWOC',
#   'Population': 81266.0,
#   'Median Age': 43.3,
#   'Household Income': 50091.0,
#   'Per Capita Income': 26138.0,
#   'Poverty Rate': 8.933625378387026,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'WISCONSIN',
#   'state_po': 'WI',
#   'county_name': 'SAUK',
#   'Population': 61953.0,
#   'Median Age': 39.9,
#   'Household Income': 52355.0,
#   'Per Capita Income': 26144.0,
#   'Poverty Rate': 9.568543896179362,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'WISCONSIN',
#   'state_po': 'WI',
#   'county_name': 'BURNETT',
#   'Population': 15528.0,
#   'Median Age': 49.3,
#   'Household Income': 39382.0,
#   'Per Capita Income': 22887.0,
#   'Poverty Rate': 18.308861411643484,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'WISCONSIN',
#   'state_po': 'WI',
#   'county_name': 'CHIPPEWA',
#   'Population': 62362.0,
#   'Median Age': 40.2,
#   'Household Income': 50327.0,
#   'Per Capita Income': 24768.0,
#   'Poverty Rate': 10.605817645360958,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'WISCONSIN',
#   'state_po': 'WI',
#   'county_name': 'DOOR',
#   'Population': 27872.0,
#   'Median Age': 49.6,
#   'Household Income': 48707.0,
#   'Per Capita Income': 30509.0,
#   'Poverty Rate': 11.194029850746269,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'WISCONSIN',
#   'state_po': 'WI',
#   'county_name': 'FOND DU LAC',
#   'Population': 101577.0,
#   'Median Age': 40.3,
#   'Household Income': 53399.0,
#   'Per Capita Income': 26331.0,
#   'Poverty Rate': 9.321992183269835,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'WISCONSIN',
#   'state_po': 'WI',
#   'county_name': 'JACKSON',
#   'Population': 20436.0,
#   'Median Age': 41.6,
#   'Household Income': 43098.0,
#   'Per Capita Income': 21526.0,
#   'Poverty Rate': 15.272068898023097,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'WISCONSIN',
#   'state_po': 'WI',
#   'county_name': 'PEPIN',
#   'Population': 7458.0,
#   'Median Age': 43.8,
#   'Household Income': 49544.0,
#   'Per Capita Income': 24436.0,
#   'Poverty Rate': 10.311075355323142,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'WISCONSIN',
#   'state_po': 'WI',
#   'county_name': 'OZAUKEE',
#   'Population': 86429.0,
#   'Median Age': 43.0,
#   'Household Income': 75854.0,
#   'Per Capita Income': 42180.0,
#   'Poverty Rate': 4.542456814263731,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'WISCONSIN',
#   'state_po': 'WI',
#   'county_name': 'RICHLAND',
#   'Population': 18020.0,
#   'Median Age': 42.9,
#   'Household Income': 44821.0,
#   'Per Capita Income': 22591.0,
#   'Poverty Rate': 10.960044395116537,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'WISCONSIN',
#   'state_po': 'WI',
#   'county_name': 'ROCK',
#   'Population': 160356.0,
#   'Median Age': 38.3,
#   'Household Income': 50316.0,
#   'Per Capita Income': 24162.0,
#   'Poverty Rate': 13.229314774626456,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'WISCONSIN',
#   'state_po': 'WI',
#   'county_name': 'WAUSHARA',
#   'Population': 24565.0,
#   'Median Age': 46.3,
#   'Household Income': 43582.0,
#   'Per Capita Income': 22587.0,
#   'Poverty Rate': 11.630368410339914,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'WISCONSIN',
#   'state_po': 'WI',
#   'county_name': 'BAYFIELD',
#   'Population': 15078.0,
#   'Median Age': 49.3,
#   'Household Income': 44626.0,
#   'Per Capita Income': 25485.0,
#   'Poverty Rate': 13.469956227616395,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'WISCONSIN',
#   'state_po': 'WI',
#   'county_name': 'LAFAYETTE',
#   'Population': 16836.0,
#   'Median Age': 41.0,
#   'Household Income': 49263.0,
#   'Per Capita Income': 23006.0,
#   'Poverty Rate': 11.380375386077453,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'WISCONSIN',
#   'state_po': 'WI',
#   'county_name': 'PIERCE',
#   'Population': 40842.0,
#   'Median Age': 34.6,
#   'Household Income': 61153.0,
#   'Per Capita Income': 27644.0,
#   'Poverty Rate': 11.568973115910092,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'WISCONSIN',
#   'state_po': 'WI',
#   'county_name': 'WOOD',
#   'Population': 74591.0,
#   'Median Age': 42.5,
#   'Household Income': 46999.0,
#   'Per Capita Income': 25779.0,
#   'Poverty Rate': 9.919427276749206,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'WISCONSIN',
#   'state_po': 'WI',
#   'county_name': 'CALUMET',
#   'Population': 48960.0,
#   'Median Age': 38.2,
#   'Household Income': 64982.0,
#   'Per Capita Income': 28682.0,
#   'Poverty Rate': 5.555555555555555,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'WISCONSIN',
#   'state_po': 'WI',
#   'county_name': 'FLORENCE',
#   'Population': 4486.0,
#   'Median Age': 48.5,
#   'Household Income': 44652.0,
#   'Per Capita Income': 22128.0,
#   'Poverty Rate': 13.196611680784663,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'WISCONSIN',
#   'state_po': 'WI',
#   'county_name': 'KENOSHA',
#   'Population': 166373.0,
#   'Median Age': 36.5,
#   'Household Income': 55117.0,
#   'Per Capita Income': 27012.0,
#   'Poverty Rate': 11.880533500027047,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'WYOMING',
#   'state_po': 'WY',
#   'county_name': 'LINCOLN',
#   'Population': 17960.0,
#   'Median Age': 37.5,
#   'Household Income': 62542.0,
#   'Per Capita Income': 26459.0,
#   'Poverty Rate': 7.0768374164810695,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'WYOMING',
#   'state_po': 'WY',
#   'county_name': 'JOHNSON',
#   'Population': 8564.0,
#   'Median Age': 44.9,
#   'Household Income': 57175.0,
#   'Per Capita Income': 28972.0,
#   'Poverty Rate': 7.858477347034096,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'WYOMING',
#   'state_po': 'WY',
#   'county_name': 'LARAMIE',
#   'Population': 91719.0,
#   'Median Age': 37.3,
#   'Household Income': 54596.0,
#   'Per Capita Income': 28736.0,
#   'Poverty Rate': 10.138575431480936,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'WYOMING',
#   'state_po': 'WY',
#   'county_name': 'CONVERSE',
#   'Population': 13779.0,
#   'Median Age': 40.0,
#   'Household Income': 62554.0,
#   'Per Capita Income': 30030.0,
#   'Poverty Rate': 8.17911314318891,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'WYOMING',
#   'state_po': 'WY',
#   'county_name': 'TETON',
#   'Population': 21326.0,
#   'Median Age': 36.6,
#   'Household Income': 69020.0,
#   'Per Capita Income': 41755.0,
#   'Poverty Rate': 7.676076151176967,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'TENNESSEE',
#   'state_po': 'TN',
#   'county_name': 'WARREN',
#   'Population': 39767.0,
#   'Median Age': 38.7,
#   'Household Income': 34008.0,
#   'Per Capita Income': 19357.0,
#   'Poverty Rate': 22.54633238614932,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'TENNESSEE',
#   'state_po': 'TN',
#   'county_name': 'WASHINGTON',
#   'Population': 122840.0,
#   'Median Age': 39.6,
#   'Household Income': 42995.0,
#   'Per Capita Income': 25381.0,
#   'Poverty Rate': 16.725822207749918,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'TENNESSEE',
#   'state_po': 'TN',
#   'county_name': 'WEAKLEY',
#   'Population': 34802.0,
#   'Median Age': 36.8,
#   'Household Income': 35509.0,
#   'Per Capita Income': 20150.0,
#   'Poverty Rate': 19.113844031952187,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'TENNESSEE',
#   'state_po': 'TN',
#   'county_name': 'BENTON',
#   'Population': 16420.0,
#   'Median Age': 46.0,
#   'Household Income': 33663.0,
#   'Per Capita Income': 18310.0,
#   'Poverty Rate': 20.109622411693056,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'TENNESSEE',
#   'state_po': 'TN',
#   'county_name': 'BLEDSOE',
#   'Population': 12898.0,
#   'Median Age': 42.2,
#   'Household Income': 31388.0,
#   'Per Capita Income': 14353.0,
#   'Poverty Rate': 20.92572491859203,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'TENNESSEE',
#   'state_po': 'TN',
#   'county_name': 'CAMPBELL',
#   'Population': 40629.0,
#   'Median Age': 41.8,
#   'Household Income': 31312.0,
#   'Per Capita Income': 16601.0,
#   'Poverty Rate': 23.293706465824904,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'TENNESSEE',
#   'state_po': 'TN',
#   'county_name': 'CANNON',
#   'Population': 13797.0,
#   'Median Age': 40.4,
#   'Household Income': 40998.0,
#   'Per Capita Income': 18652.0,
#   'Poverty Rate': 16.228165543234038,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'TENNESSEE',
#   'state_po': 'TN',
#   'county_name': 'HOUSTON',
#   'Population': 8375.0,
#   'Median Age': 41.3,
#   'Household Income': 34595.0,
#   'Per Capita Income': 18555.0,
#   'Poverty Rate': 21.134328358208954,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MAINE',
#   'state_po': 'ME',
#   'county_name': 'LINCOLN',
#   'Population': 34440.0,
#   'Median Age': 48.1,
#   'Household Income': 50494.0,
#   'Per Capita Income': 27839.0,
#   'Poverty Rate': 10.917537746806039,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'MAINE',
#   'state_po': 'ME',
#   'county_name': 'WALDO',
#   'Population': 38761.0,
#   'Median Age': 44.2,
#   'Household Income': 42238.0,
#   'Per Capita Income': 23020.0,
#   'Poverty Rate': 15.187946647403317,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'MAINE',
#   'state_po': 'ME',
#   'county_name': 'PENOBSCOT',
#   'Population': 153742.0,
#   'Median Age': 40.0,
#   'Household Income': 43382.0,
#   'Per Capita Income': 23307.0,
#   'Poverty Rate': 16.368331360330945,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'MAINE',
#   'state_po': 'ME',
#   'county_name': 'PISCATAQUIS',
#   'Population': 17432.0,
#   'Median Age': 48.1,
#   'Household Income': 36606.0,
#   'Per Capita Income': 21292.0,
#   'Poverty Rate': 17.433455713630106,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MAINE',
#   'state_po': 'ME',
#   'county_name': 'ANDROSCOGGIN',
#   'Population': 107766.0,
#   'Median Age': 39.8,
#   'Household Income': 44826.0,
#   'Per Capita Income': 24268.0,
#   'Poverty Rate': 14.370023940760536,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'MAINE',
#   'state_po': 'ME',
#   'county_name': 'AROOSTOOK',
#   'Population': 71757.0,
#   'Median Age': 45.2,
#   'Household Income': 37434.0,
#   'Per Capita Income': 21024.0,
#   'Poverty Rate': 15.5092882924314,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'MAINE',
#   'state_po': 'ME',
#   'county_name': 'WASHINGTON',
#   'Population': 32832.0,
#   'Median Age': 45.9,
#   'Household Income': 36486.0,
#   'Per Capita Income': 20015.0,
#   'Poverty Rate': 19.139863547758285,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'MAINE',
#   'state_po': 'ME',
#   'county_name': 'CUMBERLAND',
#   'Population': 282143.0,
#   'Median Age': 41.1,
#   'Household Income': 57159.0,
#   'Per Capita Income': 32549.0,
#   'Poverty Rate': 10.744551521746065,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'MAINE',
#   'state_po': 'ME',
#   'county_name': 'KNOX',
#   'Population': 39848.0,
#   'Median Age': 46.6,
#   'Household Income': 47714.0,
#   'Per Capita Income': 27141.0,
#   'Poverty Rate': 11.202569765107409,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'MAINE',
#   'state_po': 'ME',
#   'county_name': 'SAGADAHOC',
#   'Population': 35394.0,
#   'Median Age': 43.8,
#   'Household Income': 55634.0,
#   'Per Capita Income': 28122.0,
#   'Poverty Rate': 9.94236311239193,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'MAINE',
#   'state_po': 'ME',
#   'county_name': 'YORK',
#   'Population': 197861.0,
#   'Median Age': 43.0,
#   'Household Income': 56656.0,
#   'Per Capita Income': 28496.0,
#   'Poverty Rate': 9.339384719575865,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'MAINE',
#   'state_po': 'ME',
#   'county_name': 'KENNEBEC',
#   'Population': 122022.0,
#   'Median Age': 42.7,
#   'Household Income': 47424.0,
#   'Per Capita Income': 25652.0,
#   'Poverty Rate': 12.200258969693989,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'MAINE',
#   'state_po': 'ME',
#   'county_name': 'FRANKLIN',
#   'Population': 30704.0,
#   'Median Age': 43.3,
#   'Household Income': 39416.0,
#   'Per Capita Income': 21744.0,
#   'Poverty Rate': 16.405028660760813,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'MAINE',
#   'state_po': 'ME',
#   'county_name': 'SOMERSET',
#   'Population': 52098.0,
#   'Median Age': 43.9,
#   'Household Income': 38141.0,
#   'Per Capita Income': 21025.0,
#   'Poverty Rate': 17.91047640984299,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'MAINE',
#   'state_po': 'ME',
#   'county_name': 'HANCOCK',
#   'Population': 54470.0,
#   'Median Age': 46.3,
#   'Household Income': 48635.0,
#   'Per Capita Income': 28071.0,
#   'Poverty Rate': 12.311364053607491,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'MARYLAND',
#   'state_po': 'MD',
#   'county_name': 'WORCESTER',
#   'Population': 51398.0,
#   'Median Age': 48.1,
#   'Household Income': 58138.0,
#   'Per Capita Income': 32704.0,
#   'Poverty Rate': 10.809759134596677,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MARYLAND',
#   'state_po': 'MD',
#   'county_name': 'SOMERSET',
#   'Population': 26402.0,
#   'Median Age': 36.9,
#   'Household Income': 41558.0,
#   'Per Capita Income': 17168.0,
#   'Poverty Rate': 14.942049844708734,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'MARYLAND',
#   'state_po': 'MD',
#   'county_name': 'TALBOT',
#   'Population': 37746.0,
#   'Median Age': 47.3,
#   'Household Income': 62942.0,
#   'Per Capita Income': 37767.0,
#   'Poverty Rate': 7.476288878291739,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MARYLAND',
#   'state_po': 'MD',
#   'county_name': 'HARFORD',
#   'Population': 245396.0,
#   'Median Age': 39.5,
#   'Household Income': 80441.0,
#   'Per Capita Income': 34953.0,
#   'Poverty Rate': 7.389280998875288,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MARYLAND',
#   'state_po': 'MD',
#   'county_name': 'HOWARD',
#   'Population': 288676.0,
#   'Median Age': 38.3,
#   'Household Income': 107821.0,
#   'Per Capita Income': 47662.0,
#   'Poverty Rate': 4.331153265252394,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'MARYLAND',
#   'state_po': 'MD',
#   'county_name': "PRINCE GEORGE'S",
#   'Population': 865443.0,
#   'Median Age': 35.0,
#   'Household Income': 73568.0,
#   'Per Capita Income': 32254.0,
#   'Poverty Rate': 8.459829243520371,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'MARYLAND',
#   'state_po': 'MD',
#   'county_name': 'BALTIMORE',
#   'Population': 807318.0,
#   'Median Age': 39.0,
#   'Household Income': 66068.0,
#   'Per Capita Income': 34447.0,
#   'Poverty Rate': 8.339836347015675,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'MARYLAND',
#   'state_po': 'MD',
#   'county_name': 'FREDERICK',
#   'Population': 234268.0,
#   'Median Age': 38.5,
#   'Household Income': 83706.0,
#   'Per Capita Income': 36472.0,
#   'Poverty Rate': 5.588044461898338,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MARYLAND',
#   'state_po': 'MD',
#   'county_name': 'GARRETT',
#   'Population': 30079.0,
#   'Median Age': 42.9,
#   'Household Income': 45354.0,
#   'Per Capita Income': 24904.0,
#   'Poverty Rate': 12.623424980883673,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MARYLAND',
#   'state_po': 'MD',
#   'county_name': 'KENT',
#   'Population': 20184.0,
#   'Median Age': 45.3,
#   'Household Income': 54614.0,
#   'Per Capita Income': 32579.0,
#   'Poverty Rate': 10.062425683709868,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MARYLAND',
#   'state_po': 'MD',
#   'county_name': 'CARROLL',
#   'Population': 167249.0,
#   'Median Age': 41.1,
#   'Household Income': 83155.0,
#   'Per Capita Income': 35242.0,
#   'Poverty Rate': 5.400331242638222,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MARYLAND',
#   'state_po': 'MD',
#   'county_name': "QUEEN ANNE'S",
#   'Population': 47894.0,
#   'Median Age': 42.2,
#   'Household Income': 86013.0,
#   'Per Capita Income': 36526.0,
#   'Poverty Rate': 7.368355117551259,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MARYLAND',
#   'state_po': 'MD',
#   'county_name': 'CHARLES',
#   'Population': 147107.0,
#   'Median Age': 37.2,
#   'Household Income': 93063.0,
#   'Per Capita Income': 37157.0,
#   'Poverty Rate': 6.664536697777808,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'MARYLAND',
#   'state_po': 'MD',
#   'county_name': 'WASHINGTON',
#   'Population': 147882.0,
#   'Median Age': 39.8,
#   'Household Income': 54561.0,
#   'Per Capita Income': 26356.0,
#   'Poverty Rate': 11.298873426110006,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MARYLAND',
#   'state_po': 'MD',
#   'county_name': 'WICOMICO',
#   'Population': 98940.0,
#   'Median Age': 35.6,
#   'Household Income': 50639.0,
#   'Per Capita Income': 25417.0,
#   'Poverty Rate': 15.601374570446735,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MARYLAND',
#   'state_po': 'MD',
#   'county_name': 'CAROLINE',
#   'Population': 32947.0,
#   'Median Age': 38.9,
#   'Household Income': 60735.0,
#   'Per Capita Income': 25300.0,
#   'Poverty Rate': 12.65365587155128,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MASSACHUSETTS',
#   'state_po': 'MA',
#   'county_name': 'SUFFOLK',
#   'Population': 724502.0,
#   'Median Age': 31.6,
#   'Household Income': 52700.0,
#   'Per Capita Income': 32429.0,
#   'Poverty Rate': 19.557986037305625,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'MASSACHUSETTS',
#   'state_po': 'MA',
#   'county_name': 'DUKES',
#   'Population': 16581.0,
#   'Median Age': 45.4,
#   'Household Income': 65896.0,
#   'Per Capita Income': 33125.0,
#   'Poverty Rate': 10.72311682045715,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'MASSACHUSETTS',
#   'state_po': 'MA',
#   'county_name': 'MIDDLESEX',
#   'Population': 1507558.0,
#   'Median Age': 38.5,
#   'Household Income': 81420.0,
#   'Per Capita Income': 42289.0,
#   'Poverty Rate': 7.648660947041507,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'MASSACHUSETTS',
#   'state_po': 'MA',
#   'county_name': 'BRISTOL',
#   'Population': 548739.0,
#   'Median Age': 39.9,
#   'Household Income': 55995.0,
#   'Per Capita Income': 28744.0,
#   'Poverty Rate': 11.697911028740439,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'MASSACHUSETTS',
#   'state_po': 'MA',
#   'county_name': 'HAMPDEN',
#   'Population': 464072.0,
#   'Median Age': 38.8,
#   'Household Income': 49729.0,
#   'Per Capita Income': 25646.0,
#   'Poverty Rate': 16.557560033787862,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'ARIZONA',
#   'state_po': 'AZ',
#   'county_name': 'PIMA',
#   'Population': 981048.0,
#   'Median Age': 37.7,
#   'Household Income': 46443.0,
#   'Per Capita Income': 25525.0,
#   'Poverty Rate': 18.044478965351338,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'ARIZONA',
#   'state_po': 'AZ',
#   'county_name': 'MARICOPA',
#   'Population': 3841819.0,
#   'Median Age': 34.6,
#   'Household Income': 54385.0,
#   'Per Capita Income': 27552.0,
#   'Poverty Rate': 15.609819202830742,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'ARIZONA',
#   'state_po': 'AZ',
#   'county_name': 'GRAHAM',
#   'Population': 37115.0,
#   'Median Age': 31.8,
#   'Household Income': 44421.0,
#   'Per Capita Income': 16967.0,
#   'Poverty Rate': 20.013471642193185,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'ARIZONA',
#   'state_po': 'AZ',
#   'county_name': 'SANTA CRUZ',
#   'Population': 47057.0,
#   'Median Age': 35.5,
#   'Household Income': 37692.0,
#   'Per Capita Income': 17116.0,
#   'Poverty Rate': 26.56140425441486,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'ARIZONA',
#   'state_po': 'AZ',
#   'county_name': 'LA PAZ',
#   'Population': 20460.0,
#   'Median Age': 54.1,
#   'Household Income': 35093.0,
#   'Per Capita Income': 21854.0,
#   'Poverty Rate': 20.0,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'ARIZONA',
#   'state_po': 'AZ',
#   'county_name': 'MOHAVE',
#   'Population': 201216.0,
#   'Median Age': 47.4,
#   'Household Income': 39383.0,
#   'Per Capita Income': 20725.0,
#   'Poverty Rate': 17.9682530216285,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'ARIZONA',
#   'state_po': 'AZ',
#   'county_name': 'COCONINO',
#   'Population': 134011.0,
#   'Median Age': 30.9,
#   'Household Income': 48320.0,
#   'Per Capita Income': 22664.0,
#   'Poverty Rate': 20.613233242047293,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'ARIZONA',
#   'state_po': 'AZ',
#   'county_name': 'YAVAPAI',
#   'Population': 211280.0,
#   'Median Age': 49.3,
#   'Household Income': 43652.0,
#   'Per Capita Income': 26335.0,
#   'Poverty Rate': 15.106967057932602,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'ARIZONA',
#   'state_po': 'AZ',
#   'county_name': 'GREENLEE',
#   'Population': 8592.0,
#   'Median Age': 33.7,
#   'Household Income': 49692.0,
#   'Per Capita Income': 20297.0,
#   'Poverty Rate': 17.202048417132215,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'ARIZONA',
#   'state_po': 'AZ',
#   'county_name': 'PINAL',
#   'Population': 368374.0,
#   'Median Age': 35.8,
#   'Household Income': 50164.0,
#   'Per Capita Income': 20901.0,
#   'Poverty Rate': 14.167123629789291,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'ARKANSAS',
#   'state_po': 'AR',
#   'county_name': 'NEVADA',
#   'Population': 9003.0,
#   'Median Age': 39.6,
#   'Household Income': 35578.0,
#   'Per Capita Income': 19786.0,
#   'Poverty Rate': 26.646673331111852,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'ARKANSAS',
#   'state_po': 'AR',
#   'county_name': 'CROSS',
#   'Population': 17891.0,
#   'Median Age': 39.4,
#   'Household Income': 39665.0,
#   'Per Capita Income': 19282.0,
#   'Poverty Rate': 15.991280532111118,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'ARKANSAS',
#   'state_po': 'AR',
#   'county_name': 'DALLAS',
#   'Population': 8122.0,
#   'Median Age': 42.9,
#   'Household Income': 30309.0,
#   'Per Capita Income': 17056.0,
#   'Poverty Rate': 17.064762373799557,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'ARKANSAS',
#   'state_po': 'AR',
#   'county_name': 'COLUMBIA',
#   'Population': 24644.0,
#   'Median Age': 36.1,
#   'Household Income': 34895.0,
#   'Per Capita Income': 18999.0,
#   'Poverty Rate': 23.17805551046908,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'ARKANSAS',
#   'state_po': 'AR',
#   'county_name': 'SALINE',
#   'Population': 107498.0,
#   'Median Age': 38.7,
#   'Household Income': 53817.0,
#   'Per Capita Income': 25843.0,
#   'Poverty Rate': 8.512716515656106,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'ARKANSAS',
#   'state_po': 'AR',
#   'county_name': 'VAN BUREN',
#   'Population': 17223.0,
#   'Median Age': 46.5,
#   'Household Income': 33900.0,
#   'Per Capita Income': 19108.0,
#   'Poverty Rate': 23.90988794054462,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'ARKANSAS',
#   'state_po': 'AR',
#   'county_name': 'IZARD',
#   'Population': 13614.0,
#   'Median Age': 47.3,
#   'Household Income': 31011.0,
#   'Per Capita Income': 17422.0,
#   'Poverty Rate': 17.78316438959894,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MICHIGAN',
#   'state_po': 'MI',
#   'county_name': 'MIDLAND',
#   'Population': 83744.0,
#   'Median Age': 40.3,
#   'Household Income': 52947.0,
#   'Per Capita Income': 29564.0,
#   'Poverty Rate': 11.967424531906763,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MICHIGAN',
#   'state_po': 'MI',
#   'county_name': 'OGEMAW',
#   'Population': 21674.0,
#   'Median Age': 47.5,
#   'Household Income': 35320.0,
#   'Per Capita Income': 19106.0,
#   'Poverty Rate': 20.245455384331457,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MICHIGAN',
#   'state_po': 'MI',
#   'county_name': 'CRAWFORD',
#   'Population': 14119.0,
#   'Median Age': 47.5,
#   'Household Income': 39982.0,
#   'Per Capita Income': 21515.0,
#   'Poverty Rate': 17.93328139386642,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MICHIGAN',
#   'state_po': 'MI',
#   'county_name': 'GRATIOT',
#   'Population': 42340.0,
#   'Median Age': 38.5,
#   'Household Income': 40224.0,
#   'Per Capita Income': 18992.0,
#   'Poverty Rate': 15.921114785073216,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MICHIGAN',
#   'state_po': 'MI',
#   'county_name': 'LENAWEE',
#   'Population': 99878.0,
#   'Median Age': 40.2,
#   'Household Income': 48528.0,
#   'Per Capita Income': 22256.0,
#   'Poverty Rate': 13.438394841706883,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'KENTUCKY',
#   'state_po': 'KY',
#   'county_name': 'BULLITT',
#   'Population': 74431.0,
#   'Median Age': 38.2,
#   'Household Income': 53922.0,
#   'Per Capita Income': 23952.0,
#   'Poverty Rate': 10.116752428423641,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'ARKANSAS',
#   'state_po': 'AR',
#   'county_name': 'INDEPENDENCE',
#   'Population': 36572.0,
#   'Median Age': 38.0,
#   'Household Income': 34374.0,
#   'Per Capita Income': 19863.0,
#   'Poverty Rate': 22.908235808815487,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'ARKANSAS',
#   'state_po': 'AR',
#   'county_name': 'LINCOLN',
#   'Population': 14167.0,
#   'Median Age': 37.7,
#   'Household Income': 34107.0,
#   'Per Capita Income': 15161.0,
#   'Poverty Rate': 22.16418437213242,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'ARKANSAS',
#   'state_po': 'AR',
#   'county_name': 'LOGAN',
#   'Population': 22352.0,
#   'Median Age': 41.7,
#   'Household Income': 37237.0,
#   'Per Capita Income': 19587.0,
#   'Poverty Rate': 15.41696492483894,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'ARKANSAS',
#   'state_po': 'AR',
#   'county_name': 'GRANT',
#   'Population': 17852.0,
#   'Median Age': 39.4,
#   'Household Income': 49063.0,
#   'Per Capita Income': 22190.0,
#   'Poverty Rate': 8.267981178579431,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'ARKANSAS',
#   'state_po': 'AR',
#   'county_name': 'CRITTENDEN',
#   'Population': 50618.0,
#   'Median Age': 33.8,
#   'Household Income': 36521.0,
#   'Per Capita Income': 19548.0,
#   'Poverty Rate': 24.465605120708048,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'ARKANSAS',
#   'state_po': 'AR',
#   'county_name': 'FRANKLIN',
#   'Population': 18110.0,
#   'Median Age': 40.8,
#   'Household Income': 35918.0,
#   'Per Capita Income': 18694.0,
#   'Poverty Rate': 18.371065709552735,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'ARKANSAS',
#   'state_po': 'AR',
#   'county_name': 'FAULKNER',
#   'Population': 113730.0,
#   'Median Age': 31.4,
#   'Household Income': 49008.0,
#   'Per Capita Income': 23763.0,
#   'Poverty Rate': 13.938274861514113,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'ARKANSAS',
#   'state_po': 'AR',
#   'county_name': 'PIKE',
#   'Population': 11261.0,
#   'Median Age': 39.8,
#   'Household Income': 32087.0,
#   'Per Capita Income': 18316.0,
#   'Poverty Rate': 20.41559364177249,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'ARKANSAS',
#   'state_po': 'AR',
#   'county_name': 'JEFFERSON',
#   'Population': 76836.0,
#   'Median Age': 37.2,
#   'Household Income': 37561.0,
#   'Per Capita Income': 19300.0,
# ...
#   'state': 'MISSISSIPPI',
#   'state_po': 'MS',
#   'county_name': 'HOLMES',
#   'Population': 19207.0,
#   'Median Age': 32.2,
#   'Household Income': 22335.0,
#   'Per Capita Income': 12278.0,
#   'Poverty Rate': 41.18290206695475,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'MISSISSIPPI',
#   'state_po': 'MS',
#   'county_name': 'AMITE',
#   'Population': 13139.0,
#   'Median Age': 44.3,
#   'Household Income': 30471.0,
#   'Per Capita Income': 17036.0,
#   'Poverty Rate': 28.251769541060963,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSISSIPPI',
#   'state_po': 'MS',
#   'county_name': 'MADISON',
#   'Population': 95481.0,
#   'Median Age': 36.1,
#   'Household Income': 60195.0,
#   'Per Capita Income': 32637.0,
#   'Poverty Rate': 13.357631361213226,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSISSIPPI',
#   'state_po': 'MS',
#   'county_name': 'CALHOUN',
#   'Population': 14903.0,
#   'Median Age': 39.3,
#   'Household Income': 30768.0,
#   'Per Capita Income': 16910.0,
#   'Poverty Rate': 20.063074548748574,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSISSIPPI',
#   'state_po': 'MS',
#   'county_name': 'MARION',
#   'Population': 26810.0,
#   'Median Age': 37.8,
#   'Household Income': 31865.0,
#   'Per Capita Income': 17927.0,
#   'Poverty Rate': 24.826557254755688,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSISSIPPI',
#   'state_po': 'MS',
#   'county_name': 'TISHOMINGO',
#   'Population': 19573.0,
#   'Median Age': 42.5,
#   'Household Income': 32878.0,
#   'Per Capita Income': 18554.0,
#   'Poverty Rate': 18.12701169979053,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSISSIPPI',
#   'state_po': 'MS',
#   'county_name': 'WAYNE',
#   'Population': 20754.0,
#   'Median Age': 37.5,
#   'Household Income': 30783.0,
#   'Per Capita Income': 18039.0,
#   'Poverty Rate': 28.495711670039512,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSISSIPPI',
#   'state_po': 'MS',
#   'county_name': 'GREENE',
#   'Population': 14352.0,
#   'Median Age': 36.3,
#   'Household Income': 38836.0,
#   'Per Capita Income': 13820.0,
#   'Poverty Rate': 13.517279821627648,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSISSIPPI',
#   'state_po': 'MS',
#   'county_name': 'MARSHALL',
#   'Population': 37019.0,
#   'Median Age': 38.5,
#   'Household Income': 34459.0,
#   'Per Capita Income': 17784.0,
#   'Poverty Rate': 22.33177557470488,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'MISSISSIPPI',
#   'state_po': 'MS',
#   'county_name': 'QUITMAN',
#   'Population': 8171.0,
#   'Median Age': 38.5,
#   'Household Income': 23115.0,
#   'Per Capita Income': 13740.0,
#   'Poverty Rate': 36.60506669930241,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'MISSISSIPPI',
#   'state_po': 'MS',
#   'county_name': 'PEARL RIVER',
#   'Population': 55886.0,
#   'Median Age': 39.2,
#   'Household Income': 41940.0,
#   'Per Capita Income': 20244.0,
#   'Poverty Rate': 21.395340514619047,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSISSIPPI',
#   'state_po': 'MS',
#   'county_name': 'LEAKE',
#   'Population': 23563.0,
#   'Median Age': 32.7,
#   'Household Income': 30862.0,
#   'Per Capita Income': 15580.0,
#   'Poverty Rate': 25.57399312481433,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSISSIPPI',
#   'state_po': 'MS',
#   'county_name': 'NESHOBA',
#   'Population': 29682.0,
#   'Median Age': 35.3,
#   'Household Income': 37893.0,
#   'Per Capita Income': 19078.0,
#   'Poverty Rate': 21.70675830469645,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSISSIPPI',
#   'state_po': 'MS',
#   'county_name': 'RANKIN',
#   'Population': 142136.0,
#   'Median Age': 36.2,
#   'Household Income': 57593.0,
#   'Per Capita Income': 27051.0,
#   'Poverty Rate': 11.038019924579276,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSISSIPPI',
#   'state_po': 'MS',
#   'county_name': 'WASHINGTON',
#   'Population': 51010.0,
#   'Median Age': 35.2,
#   'Household Income': 27610.0,
#   'Per Capita Income': 16157.0,
#   'Poverty Rate': 36.81238972750441,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'MISSISSIPPI',
#   'state_po': 'MS',
#   'county_name': 'LAWRENCE',
#   'Population': 12832.0,
#   'Median Age': 40.1,
#   'Household Income': 38364.0,
#   'Per Capita Income': 19953.0,
#   'Poverty Rate': 18.298004987531172,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSISSIPPI',
#   'state_po': 'MS',
#   'county_name': 'PERRY',
#   'Population': 12217.0,
#   'Median Age': 39.4,
#   'Household Income': 35942.0,
#   'Per Capita Income': 17366.0,
#   'Poverty Rate': 20.365065073258574,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSISSIPPI',
#   'state_po': 'MS',
#   'county_name': 'CHICKASAW',
#   'Population': 17458.0,
#   'Median Age': 38.4,
#   'Household Income': 31028.0,
#   'Per Capita Income': 16396.0,
#   'Poverty Rate': 26.091190285256044,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'MISSISSIPPI',
#   'state_po': 'MS',
#   'county_name': 'CARROLL',
#   'Population': 10553.0,
#   'Median Age': 42.3,
#   'Household Income': 30568.0,
#   'Per Capita Income': 16508.0,
#   'Poverty Rate': 24.618591869610537,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSISSIPPI',
#   'state_po': 'MS',
#   'county_name': 'GEORGE',
#   'Population': 22579.0,
#   'Median Age': 36.3,
#   'Household Income': 46263.0,
#   'Per Capita Income': 20080.0,
#   'Poverty Rate': 17.064528987111917,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSISSIPPI',
#   'state_po': 'MS',
#   'county_name': 'GRENADA',
#   'Population': 21886.0,
#   'Median Age': 39.3,
#   'Household Income': 35912.0,
#   'Per Capita Income': 20594.0,
#   'Poverty Rate': 21.977519875719636,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSISSIPPI',
#   'state_po': 'MS',
#   'county_name': 'JEFFERSON',
#   'Population': 7743.0,
#   'Median Age': 38.6,
#   'Household Income': 20281.0,
#   'Per Capita Income': 11771.0,
#   'Poverty Rate': 37.99560893710448,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'MISSISSIPPI',
#   'state_po': 'MS',
#   'county_name': 'NEWTON',
#   'Population': 21687.0,
#   'Median Age': 37.8,
#   'Household Income': 35907.0,
#   'Per Capita Income': 18237.0,
#   'Poverty Rate': 18.64711578364919,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSISSIPPI',
#   'state_po': 'MS',
#   'county_name': 'PRENTISS',
#   'Population': 25384.0,
#   'Median Age': 38.7,
#   'Household Income': 33294.0,
#   'Per Capita Income': 17546.0,
#   'Poverty Rate': 23.384809328711,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSISSIPPI',
#   'state_po': 'MS',
#   'county_name': 'SHARKEY',
#   'Population': 4835.0,
#   'Median Age': 38.2,
#   'Household Income': 32340.0,
#   'Per Capita Income': 14472.0,
#   'Poverty Rate': 34.85005170630817,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'MISSISSIPPI',
#   'state_po': 'MS',
#   'county_name': 'CHOCTAW',
#   'Population': 8506.0,
#   'Median Age': 42.4,
#   'Household Income': 30180.0,
#   'Per Capita Income': 17256.0,
#   'Poverty Rate': 21.62003291794028,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSISSIPPI',
#   'state_po': 'MS',
#   'county_name': 'HANCOCK',
#   'Population': 44044.0,
#   'Median Age': 40.5,
#   'Household Income': 43727.0,
#   'Per Capita Income': 22898.0,
#   'Poverty Rate': 19.46235582599219,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSISSIPPI',
#   'state_po': 'MS',
#   'county_name': 'ITAWAMBA',
#   'Population': 23362.0,
#   'Median Age': 39.1,
#   'Household Income': 36235.0,
#   'Per Capita Income': 18457.0,
#   'Poverty Rate': 13.256570499101104,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSISSIPPI',
#   'state_po': 'MS',
#   'county_name': 'ISSAQUENA',
#   'Population': 1556.0,
#   'Median Age': 40.2,
#   'Household Income': 24474.0,
#   'Per Capita Income': 15241.0,
#   'Poverty Rate': 24.48586118251928,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'MISSISSIPPI',
#   'state_po': 'MS',
#   'county_name': 'JACKSON',
#   'Population': 139430.0,
#   'Median Age': 37.0,
#   'Household Income': 49750.0,
#   'Per Capita Income': 24158.0,
#   'Poverty Rate': 15.232016065409166,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSISSIPPI',
#   'state_po': 'MS',
#   'county_name': 'LEFLORE',
#   'Population': 32196.0,
#   'Median Age': 32.5,
#   'Household Income': 23659.0,
#   'Per Capita Income': 12972.0,
#   'Poverty Rate': 36.5231705801963,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'MISSISSIPPI',
#   'state_po': 'MS',
#   'county_name': 'TUNICA',
#   'Population': 10716.0,
#   'Median Age': 32.2,
#   'Household Income': 30463.0,
#   'Per Capita Income': 15051.0,
#   'Poverty Rate': 29.572601717058603,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'MISSISSIPPI',
#   'state_po': 'MS',
#   'county_name': 'CLAIBORNE',
#   'Population': 9681.0,
#   'Median Age': 31.7,
#   'Household Income': 24078.0,
#   'Per Capita Income': 12788.0,
#   'Poverty Rate': 33.78783183555418,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'MISSISSIPPI',
#   'state_po': 'MS',
#   'county_name': 'HARRISON',
#   'Population': 188110.0,
#   'Median Age': 35.4,
#   'Household Income': 43593.0,
#   'Per Capita Income': 23378.0,
#   'Poverty Rate': 17.629046834299082,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSISSIPPI',
#   'state_po': 'MS',
#   'county_name': 'LAUDERDALE',
#   'Population': 80204.0,
#   'Median Age': 36.9,
#   'Household Income': 36814.0,
#   'Per Capita Income': 21262.0,
#   'Poverty Rate': 22.189666350805446,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSISSIPPI',
#   'state_po': 'MS',
#   'county_name': 'LINCOLN',
#   'Population': 34850.0,
#   'Median Age': 37.5,
#   'Household Income': 37176.0,
#   'Per Capita Income': 19964.0,
#   'Poverty Rate': 21.1506456241033,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSISSIPPI',
#   'state_po': 'MS',
#   'county_name': 'SIMPSON',
#   'Population': 27476.0,
#   'Median Age': 38.1,
#   'Household Income': 37977.0,
#   'Per Capita Income': 18361.0,
#   'Poverty Rate': 21.786286213422624,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSISSIPPI',
#   'state_po': 'MS',
#   'county_name': 'WINSTON',
#   'Population': 19160.0,
#   'Median Age': 39.4,
#   'Household Income': 32094.0,
#   'Per Capita Income': 17828.0,
#   'Poverty Rate': 25.850730688935283,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSISSIPPI',
#   'state_po': 'MS',
#   'county_name': 'ATTALA',
#   'Population': 19454.0,
#   'Median Age': 39.9,
#   'Household Income': 31102.0,
#   'Per Capita Income': 17955.0,
#   'Poverty Rate': 27.660121311812482,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSISSIPPI',
#   'state_po': 'MS',
#   'county_name': 'LAMAR',
#   'Population': 55580.0,
#   'Median Age': 33.1,
#   'Household Income': 50743.0,
#   'Per Capita Income': 26958.0,
#   'Poverty Rate': 17.39834472831954,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSISSIPPI',
#   'state_po': 'MS',
#   'county_name': 'LEE',
#   'Population': 83235.0,
#   'Median Age': 35.9,
#   'Household Income': 41242.0,
#   'Per Capita Income': 22119.0,
#   'Poverty Rate': 17.987625397969605,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSISSIPPI',
#   'state_po': 'MS',
#   'county_name': 'TALLAHATCHIE',
#   'Population': 15262.0,
#   'Median Age': 35.4,
#   'Household Income': 27689.0,
#   'Per Capita Income': 13036.0,
#   'Poverty Rate': 26.45786921766479,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'MISSISSIPPI',
#   'state_po': 'MS',
#   'county_name': 'SMITH',
#   'Population': 16425.0,
#   'Median Age': 39.2,
#   'Household Income': 36519.0,
#   'Per Capita Income': 20964.0,
#   'Poverty Rate': 22.465753424657535,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSISSIPPI',
#   'state_po': 'MS',
#   'county_name': 'WARREN',
#   'Population': 48419.0,
#   'Median Age': 37.9,
#   'Household Income': 40876.0,
#   'Per Capita Income': 22413.0,
#   'Poverty Rate': 22.670852351349676,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'MISSISSIPPI',
#   'state_po': 'MS',
#   'county_name': 'CLARKE',
#   'Population': 16688.0,
#   'Median Age': 40.8,
#   'Household Income': 31831.0,
#   'Per Capita Income': 18559.0,
#   'Poverty Rate': 24.53259827420901,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'MISSISSIPPI',
#   'state_po': 'MS',
#   'county_name': 'MONTGOMERY',
#   'Population': 10866.0,
#   'Median Age': 41.1,
#   'Household Income': 30440.0,
#   'Per Capita Income': 15880.0,
#   'Poverty Rate': 32.10933186085036,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'TEXAS',
#   'state_po': 'TX',
#   'county_name': 'JASPER',
#   'Population': 35703.0,
#   'Median Age': 40.3,
#   'Household Income': 40603.0,
#   'Per Capita Income': 20582.0,
#   'Poverty Rate': 16.8025095930314,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'TEXAS',
#   'state_po': 'TX',
#   'county_name': 'JEFFERSON',
#   'Population': 251627.0,
#   'Median Age': 36.0,
#   'Household Income': 43750.0,
#   'Per Capita Income': 23479.0,
#   'Poverty Rate': 18.04098924201298,
#   'Winner': 'Democrat'},
#  {'year': 2012,
#   'state': 'TEXAS',
#   'state_po': 'TX',
#   'county_name': 'KINNEY',
#   'Population': 3574.0,
#   'Median Age': 46.4,
#   'Household Income': 34083.0,
#   'Per Capita Income': 16829.0,
#   'Poverty Rate': 28.25965304980414,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'TEXAS',
#   'state_po': 'TX',
#   'county_name': 'OLDHAM',
#   'Population': 2048.0,
#   'Median Age': 39.3,
#   'Household Income': 50993.0,
#   'Per Capita Income': 22152.0,
#   'Poverty Rate': 16.748046875,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'TEXAS',
#   'state_po': 'TX',
#   'county_name': 'LAMB',
#   'Population': 13996.0,
#   'Median Age': 36.1,
#   'Household Income': 35265.0,
#   'Per Capita Income': 17948.0,
#   'Poverty Rate': 21.263218062303515,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'TEXAS',
#   'state_po': 'TX',
#   'county_name': 'LIPSCOMB',
#   'Population': 3324.0,
#   'Median Age': 36.3,
#   'Household Income': 56131.0,
#   'Per Capita Income': 26489.0,
#   'Poverty Rate': 12.184115523465705,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'TEXAS',
#   'state_po': 'TX',
#   'county_name': 'MCCULLOCH',
#   'Population': 8281.0,
#   'Median Age': 40.8,
#   'Household Income': 36560.0,
#   'Per Capita Income': 21134.0,
#   'Poverty Rate': 20.87912087912088,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'TEXAS',
#   'state_po': 'TX',
#   'county_name': 'MASON',
#   'Population': 3978.0,
#   'Median Age': 49.8,
#   'Household Income': 44408.0,
#   'Per Capita Income': 27590.0,
#   'Poverty Rate': 15.786827551533435,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'TEXAS',
#   'state_po': 'TX',
#   'county_name': 'DICKENS',
#   'Population': 2399.0,
#   'Median Age': 45.4,
#   'Household Income': 33950.0,
#   'Per Capita Income': 19250.0,
#   'Poverty Rate': 18.549395581492288,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'TEXAS',
#   'state_po': 'TX',
#   'county_name': 'LEE',
#   'Population': 16591.0,
#   'Median Age': 40.7,
#   'Household Income': 50860.0,
#   'Per Capita Income': 23837.0,
#   'Poverty Rate': 12.392260864324031,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'TEXAS',
#   'state_po': 'TX',
#   'county_name': 'TARRANT',
#   'Population': 1814667.0,
#   'Median Age': 33.4,
#   'Household Income': 56859.0,
#   'Per Capita Income': 28125.0,
#   'Poverty Rate': 14.504699760341705,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'TEXAS',
#   'state_po': 'TX',
#   'county_name': 'ANDERSON',
#   'Population': 58269.0,
#   'Median Age': 38.8,
#   'Household Income': 41471.0,
#   'Per Capita Income': 18699.0,
#   'Poverty Rate': 15.625804458631519,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'TEXAS',
#   'state_po': 'TX',
#   'county_name': 'ELLIS',
#   'Population': 149712.0,
#   'Median Age': 35.0,
#   'Household Income': 62832.0,
#   'Per Capita Income': 26061.0,
#   'Poverty Rate': 10.62974243881586,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'TEXAS',
#   'state_po': 'TX',
#   'county_name': 'JACKSON',
#   'Population': 14075.0,
#   'Median Age': 39.0,
#   'Household Income': 47591.0,
#   'Per Capita Income': 23678.0,
#   'Poverty Rate': 12.632326820603907,
#   'Winner': 'Republican'},
#  {'year': 2012,
#   'state': 'TEXAS',
#   'state_po': 'TX',
#   'county_name': 'KERR',
#   'Population': 49469.0,
#   'Median Age': 47.3,
#   'Household Income': 43849.0,
#   'Per Capita Income': 26433.0,
#   'Poverty Rate': 13.452869473811882,
#   'Winner': 'Republican'},
#  ...]

# %%
# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
# Export data to MongoDB
db = client.census_DB
db.census.drop()
collection = db['census']
collection.insert_many(db_data_ML)

# %%
results = client.census_DB.census.find()
cluster_data = []
for result in results:
    del result['_id']
    cluster_data.append(result)

# %%
cluster_data = pd.DataFrame(cluster_data)
cluster_data
# Out:
#       year      state state_po county_name  Population  Median Age  \
# 0     2012   MISSOURI       MO        LINN     12668.0        43.0
# 1     2012   MISSOURI       MO      HOWELL     40330.0        39.6
# 2     2012   MISSOURI       MO     JOHNSON     52964.0        29.7
# 3     2012   MISSOURI       MO     LACLEDE     35507.0        39.1
# 4     2012   MISSOURI       MO      MARIES      9140.0        43.1
# ...    ...        ...      ...         ...         ...         ...
# 9002  2020  MINNESOTA       MN    RENVILLE     14572.0        44.0
# 9003  2020  MINNESOTA       MN      ROSEAU     15259.0        41.6
# 9004  2020  MINNESOTA       MN   SHERBURNE     96015.0        36.1
# 9005  2020  MINNESOTA       MN      STEELE     36710.0        39.2
# 9006  2020  MINNESOTA       MN        TODD     24603.0        43.9
#
#       Household Income  Per Capita Income  Poverty Rate      Winner
# 0              39028.0            20968.0     13.245974  Republican
# 1              34148.0            17763.0     20.300025  Republican
# 2              47960.0            21375.0     15.246205  Republican
# 3              39101.0            19788.0     18.244290  Republican
# 4              44885.0            21883.0     14.070022  Republican
# ...                ...                ...           ...         ...
# 9002           58542.0            31243.0      9.422180  Republican
# 9003           62304.0            31452.0      7.425126  Republican
# 9004           88671.0            36022.0      5.158569  Republican
# 9005           68172.0            34648.0      7.864342  Republican
# 9006           54502.0            26427.0     13.315449  Republican
#
# [9007 rows x 10 columns]
