# %%
# !pip install census
# Out:
# Requirement already satisfied: census in c:\users\sridevi\anaconda3\lib\site-packages (0.8.19)
# Requirement already satisfied: requests>=1.1.0 in c:\users\sridevi\anaconda3\lib\site-packages (from census) (2.26.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\sridevi\anaconda3\lib\site-packages (from requests>=1.1.0->census) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sridevi\anaconda3\lib\site-packages (from requests>=1.1.0->census) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sridevi\anaconda3\lib\site-packages (from requests>=1.1.0->census) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sridevi\anaconda3\lib\site-packages (from requests>=1.1.0->census) (3.2)

# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
from census import Census

# Census API Key
from config import api_key
#c = Census(api_key, year=2016)

# %%
# Run Census Search to retrieve data on all zip codes (2013 ACS5 Census)
# See: https://github.com/CommerceDataService/census-wrapper for library documentation
# See: https://gist.github.com/afhaque/60558290d6efd892351c4b64e5c01e9b for labels
def get_census(year):
    c = Census(api_key, year=year)
    census_data = c.acs5.get(("NAME", "B19013_001E", "B01003_001E", "B01002_001E",
                          "B19301_001E",
                          "B17001_002E"), 
                         {'for': 'county:*'})
                        # {'for': 'zip code tabulation area:*'})

# Convert to DataFrame
    census_pd = pd.DataFrame(census_data)

# Column Reordering
    census_pd = census_pd.rename(columns={"B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B17001_002E": "Poverty Count",
                                      "NAME": "Name", "county": "County"
                                      })

# Add in Poverty Rate (Poverty Count / Population)
    census_pd["Poverty Rate"] = 100 * \
        census_pd["Poverty Count"].astype(
            int) / census_pd["Population"].astype(int)

# Final DataFrame
    census_pd = census_pd[["Name","County", "Population", "Median Age", "Household Income",
                           "Per Capita Income", "Poverty Count", "Poverty Rate"]]

    census_pd['county_name'] = census_pd['Name'].str.replace(r" County,(.*)",'').str.upper()
    census_pd['state'] = census_pd['Name'].str.replace(r"(.*) County, ",'').str.upper()
# Visualize
    
    return census_pd

census_2016 = get_census(2016)
census_2016.head()
census_2016['year'] = 2016

census_2020 = get_census(2020)
census_2020['year'] = 2020
census_2020.head()
census = pd.concat([census_2016,census_2020])
# Out:
# C:\Users\nico.cosereanu\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:33: FutureWarning: The default value of regex will change from True to False in a future version.
# C:\Users\nico.cosereanu\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:34: FutureWarning: The default value of regex will change from True to False in a future version.

# %%
census.dtypes
# Out:
# Name                  object
# County                object
# Population           float64
# Median Age           float64
# Household Income     float64
# Per Capita Income    float64
# Poverty Count        float64
# Poverty Rate         float64
# county_name           object
# state                 object
# year                   int64
# dtype: object

# %%
census = census[census['Household Income']>0]
census
# Out:
#                              Name County  Population  Median Age  \
# 0         Wright County, Missouri    229     18378.0        41.9
# 1           Clay County, Missouri    047    233135.0        36.8
# 2           Dent County, Missouri    065     15578.0        43.1
# 3         Saline County, Missouri    195     23214.0        37.4
# 4          Worth County, Missouri    227      2061.0        47.9
# ...                           ...    ...         ...         ...
# 3216   Renville County, Minnesota    129     14572.0        44.0
# 3217     Roseau County, Minnesota    135     15259.0        41.6
# 3218  Sherburne County, Minnesota    141     96015.0        36.1
# 3219     Steele County, Minnesota    147     36710.0        39.2
# 3220       Todd County, Minnesota    153     24603.0        43.9
#
#       Household Income  Per Capita Income  Poverty Count  Poverty Rate  \
# 0              30581.0            18502.0         4560.0     24.812276
# 1              63702.0            30531.0        20867.0      8.950608
# 2              38020.0            19929.0         3426.0     21.992554
# 3              40645.0            20446.0         3748.0     16.145429
# 4              44974.0            23292.0          262.0     12.712276
# ...                ...                ...            ...           ...
# 3216           58542.0            31243.0         1373.0      9.422180
# 3217           62304.0            31452.0         1133.0      7.425126
# 3218           88671.0            36022.0         4953.0      5.158569
# 3219           68172.0            34648.0         2887.0      7.864342
# 3220           54502.0            26427.0         3276.0     13.315449
#
#      county_name      state  year
# 0         WRIGHT   MISSOURI  2016
# 1           CLAY   MISSOURI  2016
# 2           DENT   MISSOURI  2016
# 3         SALINE   MISSOURI  2016
# 4          WORTH   MISSOURI  2016
# ...          ...        ...   ...
# 3216    RENVILLE  MINNESOTA  2020
# 3217      ROSEAU  MINNESOTA  2020
# 3218   SHERBURNE  MINNESOTA  2020
# 3219      STEELE  MINNESOTA  2020
# 3220        TODD  MINNESOTA  2020
#
# [6440 rows x 11 columns]

# %%
census.to_csv("clean_census.csv", encoding="utf-8", index=False)

# %%
# # Save as a csv
# # Note to avoid any issues later, use encoding="utf-8"
winners_pd=pd.read_csv("countypres_2000-2020_with_winner.csv")
# winners_pd = winners_pd[((winners_pd['year'] == 2016) | (winners_pd['year'] == 2020)) & (winners_pd['state']== 'GEORGIA') & (winners_pd['county_name']== "WORTH")]
winners_pd
# Out:
#        year    state state_po county_name  county_fips        office  \
# 0      2000  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 1      2000  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 2      2000  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 3      2000  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 4      2000  ALABAMA       AL     BALDWIN       1003.0  US PRESIDENT
# ...     ...      ...      ...         ...          ...           ...
# 72612  2020  WYOMING       WY    WASHAKIE      56043.0  US PRESIDENT
# 72613  2020  WYOMING       WY      WESTON      56045.0  US PRESIDENT
# 72614  2020  WYOMING       WY      WESTON      56045.0  US PRESIDENT
# 72615  2020  WYOMING       WY      WESTON      56045.0  US PRESIDENT
# 72616  2020  WYOMING       WY      WESTON      56045.0  US PRESIDENT
#
#                candidate        party  candidatevotes  totalvotes   version  \
# 0                AL GORE     DEMOCRAT            4942       17208  20220315
# 1         GEORGE W. BUSH   REPUBLICAN           11993       17208  20220315
# 2            RALPH NADER        GREEN             160       17208  20220315
# 3                  OTHER        OTHER             113       17208  20220315
# 4                AL GORE     DEMOCRAT           13997       56480  20220315
# ...                  ...          ...             ...         ...       ...
# 72612     DONALD J TRUMP   REPUBLICAN            3245        4032  20220315
# 72613  JOSEPH R BIDEN JR     DEMOCRAT             360        3560  20220315
# 72614       JO JORGENSEN  LIBERTARIAN              46        3560  20220315
# 72615              OTHER        OTHER              47        3560  20220315
# 72616     DONALD J TRUMP   REPUBLICAN            3107        3560  20220315
#
#         mode               Concat      Winner
# 0      TOTAL   2000ALABAMAAUTAUGA  Republican
# 1      TOTAL   2000ALABAMAAUTAUGA  Republican
# 2      TOTAL   2000ALABAMAAUTAUGA  Republican
# 3      TOTAL   2000ALABAMAAUTAUGA  Republican
# 4      TOTAL   2000ALABAMABALDWIN  Republican
# ...      ...                  ...         ...
# 72612  TOTAL  2020WYOMINGWASHAKIE  Republican
# 72613  TOTAL    2020WYOMINGWESTON  Republican
# 72614  TOTAL    2020WYOMINGWESTON  Republican
# 72615  TOTAL    2020WYOMINGWESTON  Republican
# 72616  TOTAL    2020WYOMINGWESTON  Republican
#
# [72617 rows x 14 columns]

# %%
# dem_pd = winners_pd[winners_pd['party'] == 'DEMOCRAT']
# dem_pd
#  #& ((winners_pd['party'] == 'DEMOCRAT') | (winners_pd['party'] == 'REPUBLICAN') )

# %%
# rep_pd = winners_pd[winners_pd['party'] == 'REPUBLICAN']
# rep_pd

# %%
# merge_pd=dem_pd.merge(rep_pd, on = ['year','state', 'county_name'])
# merge_pd.head(100)

# %%
# merge_pd['winner'] = np.where(merge_pd['candidatevotes_x'] > merge_pd['candidatevotes_y'], merge_pd['party_x'], merge_pd['party_y'])
# merge_pd = merge_pd[['year','state','county_name','winner']]
# merge_pd

# %%
#Dave's code
winners_pd = winners_pd[((winners_pd['year'] == 2016) | (winners_pd['year'] == 2020))]
winners_pd = winners_pd[((winners_pd['party'] == 'DEMOCRAT') | (winners_pd['party'] == 'REPUBLICAN'))]
#winners_pd = winners_pd[((winners_pd['state']== 'GEORGIA') & (winners_pd['county_name']== "WORTH"))]
#winners_pd.head(100)
winners_pd=winners_pd.drop_duplicates(subset=['state_po','county_name', 'year'],keep='first')

# %%
winners_pd
# Out:
#        year    state state_po county_name  county_fips        office  \
# 40517  2016  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 40520  2016  ALABAMA       AL     BALDWIN       1003.0  US PRESIDENT
# 40523  2016  ALABAMA       AL     BARBOUR       1005.0  US PRESIDENT
# 40526  2016  ALABAMA       AL        BIBB       1007.0  US PRESIDENT
# 40529  2016  ALABAMA       AL      BLOUNT       1009.0  US PRESIDENT
# ...     ...      ...      ...         ...          ...           ...
# 72597  2020  WYOMING       WY  SWEETWATER      56037.0  US PRESIDENT
# 72601  2020  WYOMING       WY       TETON      56039.0  US PRESIDENT
# 72605  2020  WYOMING       WY       UINTA      56041.0  US PRESIDENT
# 72609  2020  WYOMING       WY    WASHAKIE      56043.0  US PRESIDENT
# 72613  2020  WYOMING       WY      WESTON      56045.0  US PRESIDENT
#
#                candidate     party  candidatevotes  totalvotes   version  \
# 40517    HILLARY CLINTON  DEMOCRAT            5936       24973  20220315
# 40520    HILLARY CLINTON  DEMOCRAT           18458       95215  20220315
# 40523    HILLARY CLINTON  DEMOCRAT            4871       10469  20220315
# 40526    HILLARY CLINTON  DEMOCRAT            1874        8819  20220315
# 40529    HILLARY CLINTON  DEMOCRAT            2156       25588  20220315
# ...                  ...       ...             ...         ...       ...
# 72597  JOSEPH R BIDEN JR  DEMOCRAT            3823       16698  20220315
# 72601  JOSEPH R BIDEN JR  DEMOCRAT            9848       14787  20220315
# 72605  JOSEPH R BIDEN JR  DEMOCRAT            1591        9459  20220315
# 72609  JOSEPH R BIDEN JR  DEMOCRAT             651        4032  20220315
# 72613  JOSEPH R BIDEN JR  DEMOCRAT             360        3560  20220315
#
#         mode                 Concat      Winner
# 40517  TOTAL     2016ALABAMAAUTAUGA  Republican
# 40520  TOTAL     2016ALABAMABALDWIN  Republican
# 40523  TOTAL     2016ALABAMABARBOUR  Republican
# 40526  TOTAL        2016ALABAMABIBB  Republican
# 40529  TOTAL      2016ALABAMABLOUNT  Republican
# ...      ...                    ...         ...
# 72597  TOTAL  2020WYOMINGSWEETWATER  Republican
# 72601  TOTAL       2020WYOMINGTETON    Democrat
# 72605  TOTAL       2020WYOMINGUINTA  Republican
# 72609  TOTAL    2020WYOMINGWASHAKIE  Republican
# 72613  TOTAL      2020WYOMINGWESTON  Republican
#
# [6308 rows x 14 columns]

# %%
cleaned_census_data = pd.merge(census, winners_pd, how='left', left_on=['year','state', 'county_name'], right_on=['year','state', 'county_name'])

cleaned_census_data = cleaned_census_data[['year','state','state_po','county_name','Population','Median Age', 'Household Income', 'Per Capita Income', 'Poverty Rate', 'Winner']]
cleaned_census_data
# Out:
#       year      state state_po county_name  Population  Median Age  \
# 0     2016   MISSOURI       MO      WRIGHT     18378.0        41.9
# 1     2016   MISSOURI       MO        CLAY    233135.0        36.8
# 2     2016   MISSOURI       MO        DENT     15578.0        43.1
# 3     2016   MISSOURI       MO      SALINE     23214.0        37.4
# 4     2016   MISSOURI       MO       WORTH      2061.0        47.9
# ...    ...        ...      ...         ...         ...         ...
# 6435  2020  MINNESOTA       MN    RENVILLE     14572.0        44.0
# 6436  2020  MINNESOTA       MN      ROSEAU     15259.0        41.6
# 6437  2020  MINNESOTA       MN   SHERBURNE     96015.0        36.1
# 6438  2020  MINNESOTA       MN      STEELE     36710.0        39.2
# 6439  2020  MINNESOTA       MN        TODD     24603.0        43.9
#
#       Household Income  Per Capita Income  Poverty Rate      Winner
# 0              30581.0            18502.0     24.812276  Republican
# 1              63702.0            30531.0      8.950608  Republican
# 2              38020.0            19929.0     21.992554  Republican
# 3              40645.0            20446.0     16.145429  Republican
# 4              44974.0            23292.0     12.712276  Republican
# ...                ...                ...           ...         ...
# 6435           58542.0            31243.0      9.422180  Republican
# 6436           62304.0            31452.0      7.425126  Republican
# 6437           88671.0            36022.0      5.158569  Republican
# 6438           68172.0            34648.0      7.864342  Republican
# 6439           54502.0            26427.0     13.315449  Republican
#
# [6440 rows x 10 columns]

# %%
cleaned_census_data.dropna(subset =["state_po"],inplace=True)
# cleaned_census_data.drop_duplicates()
# cleaned_census_data

# %%
cleaned_census_data.groupby('year').sum()
# Out:
#        Population  Median Age  Household Income  Per Capita Income  \
# year
# 2016  307582561.0    123750.4       143834484.0         74999435.0
# 2020  315412439.0    125295.5       165020057.0         87102240.0
#
#       Poverty Rate
# year
# 2016  47062.421839
# 2020  41776.289741

# %%
cleaned_census_data.to_csv("clean_data.csv", encoding="utf-8", index=False)

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

# %%
X = cleaned_census_data.drop(['year','state', 'county_name','Winner'], axis=1)
X.head()
# Out:
#   state_po  Population  Median Age  Household Income  Per Capita Income  \
# 0       MO     18378.0        41.9           30581.0            18502.0
# 1       MO    233135.0        36.8           63702.0            30531.0
# 2       MO     15578.0        43.1           38020.0            19929.0
# 3       MO     23214.0        37.4           40645.0            20446.0
# 4       MO      2061.0        47.9           44974.0            23292.0
#
#    Poverty Rate
# 0     24.812276
# 1      8.950608
# 2     21.992554
# 3     16.145429
# 4     12.712276

# %%
y = cleaned_census_data["Winner"].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
from sklearn.preprocessing import StandardScaler

# Create a StandardScater model and fit it to the training data

X_scaler = StandardScaler()
X_scaler.fit(X_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2808\2171769438.py in <module>
#       4
#       5 X_scaler = StandardScaler()
# ----> 6 X_scaler.fit(X_train)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y, sample_weight)
#     804         # Reset internal state before fitting
#     805         self._reset()
# --> 806         return self.partial_fit(X, y, sample_weight)
#     807
#     808     def partial_fit(self, X, y=None, sample_weight=None):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sklearn\preprocessing\_data.py in partial_fit(self, X, y, sample_weight)
#     845             dtype=FLOAT_DTYPES,
#     846             force_all_finite="allow-nan",
# --> 847             reset=first_call,
#     848         )
#     849         n_features = X.shape[1]
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     564             raise ValueError("Validation should be done on X, y or both.")
#     565         elif not no_val_X and no_val_y:
# --> 566             X = check_array(X, **check_params)
#     567             out = X
#     568         elif no_val_X and not no_val_y:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     744                     array = array.astype(dtype, casting="unsafe", copy=False)
#     745                 else:
# --> 746                     array = np.asarray(array, order=order, dtype=dtype)
#     747             except ComplexWarning as complex_warning:
#     748                 raise ValueError(
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in __array__(self, dtype)
#    1991
#    1992     def __array__(self, dtype: NpDtype | None = None) -> np.ndarray:
# -> 1993         return np.asarray(self._values, dtype=dtype)
#    1994
#    1995     def __array_wrap__(
#
# ValueError: could not convert string to float: 'KS'

# %%
# Transform the training and testing data by using the X_scaler and y_scaler models

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2808\3944916935.py in <module>
#       1 # Transform the training and testing data by using the X_scaler and y_scaler models
#       2
# ----> 3 X_train_scaled = X_scaler.transform(X_train)
#       4 X_test_scaled = X_scaler.transform(X_test)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sklearn\preprocessing\_data.py in transform(self, X, copy)
#     978             estimator=self,
#     979             dtype=FLOAT_DTYPES,
# --> 980             force_all_finite="allow-nan",
#     981         )
#     982
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     564             raise ValueError("Validation should be done on X, y or both.")
#     565         elif not no_val_X and no_val_y:
# --> 566             X = check_array(X, **check_params)
#     567             out = X
#     568         elif no_val_X and not no_val_y:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     744                     array = array.astype(dtype, casting="unsafe", copy=False)
#     745                 else:
# --> 746                     array = np.asarray(array, order=order, dtype=dtype)
#     747             except ComplexWarning as complex_warning:
#     748                 raise ValueError(
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in __array__(self, dtype)
#    1991
#    1992     def __array__(self, dtype: NpDtype | None = None) -> np.ndarray:
# -> 1993         return np.asarray(self._values, dtype=dtype)
#    1994
#    1995     def __array_wrap__(
#
# ValueError: could not convert string to float: 'KS'

# %%
# Loop through different k values to find which has the highest accuracy.
# Note: We use only odd numbers because we don't want any ties.
train_scores = []
test_scores = []
for k in range(1, 20, 2):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train_scaled, y_train)
    train_score = knn.score(X_train_scaled, y_train)
    test_score = knn.score(X_test_scaled, y_test)
    train_scores.append(train_score)
    test_scores.append(test_score)
    print(f"k: {k}, Train/Test Score: {train_score:.3f}/{test_score:.3f}")
    
    
plt.plot(range(1, 20, 2), train_scores, marker='o')
plt.plot(range(1, 20, 2), test_scores, marker="x")
plt.xlabel("k neighbors")
plt.ylabel("Testing accuracy score")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2808\3590655616.py in <module>
#       5 for k in range(1, 20, 2):
#       6     knn = KNeighborsClassifier(n_neighbors=k)
# ----> 7     knn.fit(X_train_scaled, y_train)
#       8     train_score = knn.score(X_train_scaled, y_train)
#       9     test_score = knn.score(X_test_scaled, y_test)
#
# NameError: name 'X_train_scaled' is not defined

# %%
# Note that k: 11 seems to be the best choice for this dataset
knn = KNeighborsClassifier(n_neighbors=11)
knn.fit(X_train_scaled, y_train)
print('k=11 Test Acc: %.3f' % knn.score(X_test_scaled, y_test))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2808\3548852052.py in <module>
#       1 # Note that k: 11 seems to be the best choice for this dataset
#       2 knn = KNeighborsClassifier(n_neighbors=11)
# ----> 3 knn.fit(X_train_scaled, y_train)
#       4 print('k=11 Test Acc: %.3f' % knn.score(X_test_scaled, y_test))
#
# NameError: name 'X_train_scaled' is not defined
