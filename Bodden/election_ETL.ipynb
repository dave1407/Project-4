# %%
# Import dependencies 
import pandas as pd
import pymongo
import requests
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf

# %%
# Import Census CSV data 
census_data = pd.read_csv('./Resources/2016_2020_census_data.csv')
census_data
# Out:
#        Zipcode  Population  Median Age  Household Income  Per Capita Income  \
# 0         5762         513        39.2             58558            24235.0
# 1         5763        2715        43.9             54968            29674.0
# 2         5764        3370        41.3             44468            22651.0
# 3         5765        1632        46.7             56771            30786.0
# 4         5766         598        45.9             52250            33227.0
# ...        ...         ...         ...               ...                ...
# 66235    16623         552        54.9             51667            26369.0
# 66236    16627        2118        44.6             45000            24699.0
# 66237    16634         315        46.1             51500            25084.0
# 66238    16640         707        48.6             55982            28335.0
# 66239    17062        4289        43.2             73036            32621.0
#
#        Poverty Count  Poverty Rate  Year
# 0                 50      9.746589  2016
# 1                488     17.974217  2016
# 2                323      9.584570  2016
# 3                 85      5.208333  2016
# 4                 76     12.709030  2016
# ...              ...           ...   ...
# 66235             80     14.492754  2020
# 66236            324     15.297450  2020
# 66237             24      7.619048  2020
# 66238            167     23.620934  2020
# 66239            255      5.945442  2020
#
# [66240 rows x 8 columns]

# %%
# Perform some data cleansing options Drop NA
census_data.dropna(inplace=True)
census_data
# Out:
#        Zipcode  Population  Median Age  Household Income  Per Capita Income  \
# 0         5762         513        39.2             58558            24235.0
# 1         5763        2715        43.9             54968            29674.0
# 2         5764        3370        41.3             44468            22651.0
# 3         5765        1632        46.7             56771            30786.0
# 4         5766         598        45.9             52250            33227.0
# ...        ...         ...         ...               ...                ...
# 66235    16623         552        54.9             51667            26369.0
# 66236    16627        2118        44.6             45000            24699.0
# 66237    16634         315        46.1             51500            25084.0
# 66238    16640         707        48.6             55982            28335.0
# 66239    17062        4289        43.2             73036            32621.0
#
#        Poverty Count  Poverty Rate  Year
# 0                 50      9.746589  2016
# 1                488     17.974217  2016
# 2                323      9.584570  2016
# 3                 85      5.208333  2016
# 4                 76     12.709030  2016
# ...              ...           ...   ...
# 66235             80     14.492754  2020
# 66236            324     15.297450  2020
# 66237             24      7.619048  2020
# 66238            167     23.620934  2020
# 66239            255      5.945442  2020
#
# [64934 rows x 8 columns]

# %%
cleaned_census_data = census_data[census_data['Household Income']>0]
cleaned_census_data
# Out:
#        Zipcode  Population  Median Age  Household Income  Per Capita Income  \
# 0         5762         513        39.2             58558            24235.0
# 1         5763        2715        43.9             54968            29674.0
# 2         5764        3370        41.3             44468            22651.0
# 3         5765        1632        46.7             56771            30786.0
# 4         5766         598        45.9             52250            33227.0
# ...        ...         ...         ...               ...                ...
# 66235    16623         552        54.9             51667            26369.0
# 66236    16627        2118        44.6             45000            24699.0
# 66237    16634         315        46.1             51500            25084.0
# 66238    16640         707        48.6             55982            28335.0
# 66239    17062        4289        43.2             73036            32621.0
#
#        Poverty Count  Poverty Rate  Year
# 0                 50      9.746589  2016
# 1                488     17.974217  2016
# 2                323      9.584570  2016
# 3                 85      5.208333  2016
# 4                 76     12.709030  2016
# ...              ...           ...   ...
# 66235             80     14.492754  2020
# 66236            324     15.297450  2020
# 66237             24      7.619048  2020
# 66238            167     23.620934  2020
# 66239            255      5.945442  2020
#
# [61670 rows x 8 columns]

# %%
# Convert years to time since current 
cleaned_census_data['Years Since'] = cleaned_census_data['Year'].map({2016: 7, 2020: 3})
cleaned_census_data
# Out:
# C:\Users\huntl\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        Zipcode  Population  Median Age  Household Income  Per Capita Income  \
# 0         5762         513        39.2             58558            24235.0
# 1         5763        2715        43.9             54968            29674.0
# 2         5764        3370        41.3             44468            22651.0
# 3         5765        1632        46.7             56771            30786.0
# 4         5766         598        45.9             52250            33227.0
# ...        ...         ...         ...               ...                ...
# 66235    16623         552        54.9             51667            26369.0
# 66236    16627        2118        44.6             45000            24699.0
# 66237    16634         315        46.1             51500            25084.0
# 66238    16640         707        48.6             55982            28335.0
# 66239    17062        4289        43.2             73036            32621.0
#
#        Poverty Count  Poverty Rate  Year  Years Since
# 0                 50      9.746589  2016            7
# 1                488     17.974217  2016            7
# 2                323      9.584570  2016            7
# 3                 85      5.208333  2016            7
# 4                 76     12.709030  2016            7
# ...              ...           ...   ...          ...
# 66235             80     14.492754  2020            3
# 66236            324     15.297450  2020            3
# 66237             24      7.619048  2020            3
# 66238            167     23.620934  2020            3
# 66239            255      5.945442  2020            3
#
# [61670 rows x 9 columns]

# %%
zip_codes = pd.read_csv('./Resources/usazipcode.csv')
zip_codes.columns
# Out:
# Index(['zip', 'Zipcode name', 'City', 'State', 'County Name'], dtype='object')

# %%
zip_codes.dropna(inplace=True)
zip_codes['zip'] = zip_codes['zip'].astype(int)
zip_codes.dtypes
# Out:
# zip              int32
# Zipcode name    object
# City            object
# State           object
# County Name     object
# dtype: object

# %%
# Merge the census data and zipcode DF
new_df = pd.merge(census_data, zip_codes, how='left', left_on='Zipcode', right_on = 'zip')
new_df.head()
# Out:
#    Zipcode  Population  Median Age  Household Income  Per Capita Income  \
# 0     5762         513        39.2             58558            24235.0
# 1     5763        2715        43.9             54968            29674.0
# 2     5764        3370        41.3             44468            22651.0
# 3     5765        1632        46.7             56771            30786.0
# 4     5766         598        45.9             52250            33227.0
#
#    Poverty Count  Poverty Rate  Year  Years Since     zip    Zipcode name  \
# 0             50      9.746589  2016            7  5762.0  PITTSFIELD, VT
# 1            488     17.974217  2016            7  5763.0   PITTSFORD, VT
# 2            323      9.584570  2016            7  5764.0    POULTNEY, VT
# 3             85      5.208333  2016            7  5765.0     PROCTOR, VT
# 4             76     12.709030  2016            7  5766.0      RIPTON, VT
#
#          City State County Name
# 0  PITTSFIELD    VT     RUTLAND
# 1   PITTSFORD    VT     RUTLAND
# 2    POULTNEY    VT     RUTLAND
# 3     PROCTOR    VT     RUTLAND
# 4      RIPTON    VT     ADDISON

# %%
# Merge the census and zip data 
census_zip_df = new_df.drop(['zip', 'Zipcode name', 'City', 'County Name'],axis=1)
census_zip_df
# Out:
#        Zipcode  Population  Median Age  Household Income  Per Capita Income  \
# 0         5762         513        39.2             58558            24235.0
# 1         5763        2715        43.9             54968            29674.0
# 2         5764        3370        41.3             44468            22651.0
# 3         5765        1632        46.7             56771            30786.0
# 4         5766         598        45.9             52250            33227.0
# ...        ...         ...         ...               ...                ...
# 64929    16623         552        54.9             51667            26369.0
# 64930    16627        2118        44.6             45000            24699.0
# 64931    16634         315        46.1             51500            25084.0
# 64932    16640         707        48.6             55982            28335.0
# 64933    17062        4289        43.2             73036            32621.0
#
#        Poverty Count  Poverty Rate  Year  Years Since State
# 0                 50      9.746589  2016            7    VT
# 1                488     17.974217  2016            7    VT
# 2                323      9.584570  2016            7    VT
# 3                 85      5.208333  2016            7    VT
# 4                 76     12.709030  2016            7    VT
# ...              ...           ...   ...          ...   ...
# 64929             80     14.492754  2020            3    PA
# 64930            324     15.297450  2020            3    PA
# 64931             24      7.619048  2020            3    PA
# 64932            167     23.620934  2020            3    PA
# 64933            255      5.945442  2020            3    PA
#
# [64934 rows x 10 columns]

# %%
# Import the winner values by state
election_results = pd.read_csv('./Resources/2016_2020_winners.csv')
election_results
# Out:
#     STATE  Electoral Vote (D)  Electoral Vote (R) Popular Vote (D)  \
# 0      AL                 NaN                 9.0          849,624
# 1      AK                 NaN                 3.0          153,778
# 2      AZ                11.0                 NaN        1,672,143
# 3      AR                 NaN                 6.0          423,932
# 4      CA                55.0                 NaN       11,110,639
# ..    ...                 ...                 ...              ...
# 97     VA                 NaN                13.0        1,769,443
# 98     WA                 NaN                 8.0        1,221,747
# 99     WV                 5.0                 NaN          489,371
# 100    WI                10.0                 NaN        1,405,284
# 101    WY                 3.0                 NaN          174,419
#
#     Popular Vote (R) Popular Vote All Others  Total Vote      Winner  Year
# 0          1,441,170                  32,488   2,323,282  Republican  2020
# 1            189,951                  15,801     359,530  Republican  2020
# 2          1,661,686                  53,497   3,387,326    Democrat  2020
# 3            760,647                  34,490   1,219,069  Republican  2020
# 4          6,006,518                 384,223  17,501,380    Democrat  2020
# ..               ...                     ...         ...         ...   ...
# 97         1,981,473                 233,715   3,984,631  Republican  2016
# 98         1,742,718                 352,554   3,317,019  Republican  2016
# 99           188,794                  36,258     714,423    Democrat  2016
# 100        1,382,536                 188,330   2,976,150    Democrat  2016
# 101           55,973                  25,457     255,849    Democrat  2016
#
# [102 rows x 9 columns]

# %%
election_results.columns
# Out:
# Index(['STATE', 'Electoral Vote (D)', 'Electoral Vote (R)', 'Popular Vote (D)',
#        'Popular Vote (R)', 'Popular Vote All Others', 'Total Vote', 'Winner',
#        'Year'],
#       dtype='object')

# %%
# Merge the winner info with the previosuly established DF
next_df = pd.merge(census_zip_df, election_results, how='left', left_on=['State','Year'], right_on = ['STATE','Year'])
next_df.head()
# Out:
#    Zipcode  Population  Median Age  Household Income  Per Capita Income  \
# 0     5762         513        39.2             58558            24235.0
# 1     5763        2715        43.9             54968            29674.0
# 2     5764        3370        41.3             44468            22651.0
# 3     5765        1632        46.7             56771            30786.0
# 4     5766         598        45.9             52250            33227.0
#
#    Poverty Count  Poverty Rate  Year  Years Since State STATE  \
# 0             50      9.746589  2016            7    VT    VT
# 1            488     17.974217  2016            7    VT    VT
# 2            323      9.584570  2016            7    VT    VT
# 3             85      5.208333  2016            7    VT    VT
# 4             76     12.709030  2016            7    VT    VT
#
#    Electoral Vote (D)  Electoral Vote (R) Popular Vote (D) Popular Vote (R)  \
# 0                 NaN                 3.0           95,369          178,573
# 1                 NaN                 3.0           95,369          178,573
# 2                 NaN                 3.0           95,369          178,573
# 3                 NaN                 3.0           95,369          178,573
# 4                 NaN                 3.0           95,369          178,573
#
#   Popular Vote All Others Total Vote      Winner
# 0                  41,125    315,067  Republican
# 1                  41,125    315,067  Republican
# 2                  41,125    315,067  Republican
# 3                  41,125    315,067  Republican
# 4                  41,125    315,067  Republican

# %%
# Create the final dataset for ML application
db_data = next_df.drop(['Year','STATE', 'Electoral Vote (D)', 'Electoral Vote (R)', 'Popular Vote (D)',
       'Popular Vote (R)', 'Popular Vote All Others', 'Total Vote'], axis=1)
db_data
# Out:
#        Zipcode  Population  Median Age  Household Income  Per Capita Income  \
# 0         5762         513        39.2             58558            24235.0
# 1         5763        2715        43.9             54968            29674.0
# 2         5764        3370        41.3             44468            22651.0
# 3         5765        1632        46.7             56771            30786.0
# 4         5766         598        45.9             52250            33227.0
# ...        ...         ...         ...               ...                ...
# 64929    16623         552        54.9             51667            26369.0
# 64930    16627        2118        44.6             45000            24699.0
# 64931    16634         315        46.1             51500            25084.0
# 64932    16640         707        48.6             55982            28335.0
# 64933    17062        4289        43.2             73036            32621.0
#
#        Poverty Count  Poverty Rate  Years Since State      Winner
# 0                 50      9.746589            7    VT  Republican
# 1                488     17.974217            7    VT  Republican
# 2                323      9.584570            7    VT  Republican
# 3                 85      5.208333            7    VT  Republican
# 4                 76     12.709030            7    VT  Republican
# ...              ...           ...          ...   ...         ...
# 64929             80     14.492754            3    PA    Democrat
# 64930            324     15.297450            3    PA    Democrat
# 64931             24      7.619048            3    PA    Democrat
# 64932            167     23.620934            3    PA    Democrat
# 64933            255      5.945442            3    PA    Democrat
#
# [64934 rows x 10 columns]

# %%
# last drop of NA values 
db_data.dropna(inplace=True)
db_data
# Out:
#        Zipcode  Population  Median Age  Household Income  Per Capita Income  \
# 0         5762         513        39.2             58558            24235.0
# 1         5763        2715        43.9             54968            29674.0
# 2         5764        3370        41.3             44468            22651.0
# 3         5765        1632        46.7             56771            30786.0
# 4         5766         598        45.9             52250            33227.0
# ...        ...         ...         ...               ...                ...
# 64929    16623         552        54.9             51667            26369.0
# 64930    16627        2118        44.6             45000            24699.0
# 64931    16634         315        46.1             51500            25084.0
# 64932    16640         707        48.6             55982            28335.0
# 64933    17062        4289        43.2             73036            32621.0
#
#        Poverty Count  Poverty Rate  Years Since State      Winner
# 0                 50      9.746589            7    VT  Republican
# 1                488     17.974217            7    VT  Republican
# 2                323      9.584570            7    VT  Republican
# 3                 85      5.208333            7    VT  Republican
# 4                 76     12.709030            7    VT  Republican
# ...              ...           ...          ...   ...         ...
# 64929             80     14.492754            3    PA    Democrat
# 64930            324     15.297450            3    PA    Democrat
# 64931             24      7.619048            3    PA    Democrat
# 64932            167     23.620934            3    PA    Democrat
# 64933            255      5.945442            3    PA    Democrat
#
# [62714 rows x 10 columns]

# %%
# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
# Export data to MongoDB
electiondb = client.election_db
collection = electiondb.election_data
data_dict = db_data.to_dict("records")
collection.insert_many(data_dict)

# %%
#electiondb.election_data.drop()

# %%
db_electoralVote = next_df.drop(['Year','STATE', 'Popular Vote (D)',
       'Popular Vote (R)', 'Popular Vote All Others', 'Total Vote'], axis=1)

# %%
# Replacing NaN with Zeros
db_electoralVote[['Electoral Vote (D)', 'Electoral Vote (R)']] = db_electoralVote[['Electoral Vote (D)', 'Electoral Vote (R)']].fillna(0)
db_electoralVote
# Out:
#        Zipcode  Population  Median Age  Household Income  Per Capita Income  \
# 0         5762         513        39.2             58558            24235.0
# 1         5763        2715        43.9             54968            29674.0
# 2         5764        3370        41.3             44468            22651.0
# 3         5765        1632        46.7             56771            30786.0
# 4         5766         598        45.9             52250            33227.0
# ...        ...         ...         ...               ...                ...
# 64929    16623         552        54.9             51667            26369.0
# 64930    16627        2118        44.6             45000            24699.0
# 64931    16634         315        46.1             51500            25084.0
# 64932    16640         707        48.6             55982            28335.0
# 64933    17062        4289        43.2             73036            32621.0
#
#        Poverty Count  Poverty Rate  Years Since State  Electoral Vote (D)  \
# 0                 50      9.746589            7    VT                 0.0
# 1                488     17.974217            7    VT                 0.0
# 2                323      9.584570            7    VT                 0.0
# 3                 85      5.208333            7    VT                 0.0
# 4                 76     12.709030            7    VT                 0.0
# ...              ...           ...          ...   ...                 ...
# 64929             80     14.492754            3    PA                20.0
# 64930            324     15.297450            3    PA                20.0
# 64931             24      7.619048            3    PA                20.0
# 64932            167     23.620934            3    PA                20.0
# 64933            255      5.945442            3    PA                20.0
#
#        Electoral Vote (R)      Winner
# 0                     3.0  Republican
# 1                     3.0  Republican
# 2                     3.0  Republican
# 3                     3.0  Republican
# 4                     3.0  Republican
# ...                   ...         ...
# 64929                 0.0    Democrat
# 64930                 0.0    Democrat
# 64931                 0.0    Democrat
# 64932                 0.0    Democrat
# 64933                 0.0    Democrat
#
# [64934 rows x 12 columns]

# %%
db_electoralVote.dropna(inplace=True)
db_electoralVote
# Out:
#        Zipcode  Population  Median Age  Household Income  Per Capita Income  \
# 0         5762         513        39.2             58558            24235.0
# 1         5763        2715        43.9             54968            29674.0
# 2         5764        3370        41.3             44468            22651.0
# 3         5765        1632        46.7             56771            30786.0
# 4         5766         598        45.9             52250            33227.0
# ...        ...         ...         ...               ...                ...
# 64929    16623         552        54.9             51667            26369.0
# 64930    16627        2118        44.6             45000            24699.0
# 64931    16634         315        46.1             51500            25084.0
# 64932    16640         707        48.6             55982            28335.0
# 64933    17062        4289        43.2             73036            32621.0
#
#        Poverty Count  Poverty Rate  Years Since State  Electoral Vote (D)  \
# 0                 50      9.746589            7    VT                 0.0
# 1                488     17.974217            7    VT                 0.0
# 2                323      9.584570            7    VT                 0.0
# 3                 85      5.208333            7    VT                 0.0
# 4                 76     12.709030            7    VT                 0.0
# ...              ...           ...          ...   ...                 ...
# 64929             80     14.492754            3    PA                20.0
# 64930            324     15.297450            3    PA                20.0
# 64931             24      7.619048            3    PA                20.0
# 64932            167     23.620934            3    PA                20.0
# 64933            255      5.945442            3    PA                20.0
#
#        Electoral Vote (R)      Winner
# 0                     3.0  Republican
# 1                     3.0  Republican
# 2                     3.0  Republican
# 3                     3.0  Republican
# 4                     3.0  Republican
# ...                   ...         ...
# 64929                 0.0    Democrat
# 64930                 0.0    Democrat
# 64931                 0.0    Democrat
# 64932                 0.0    Democrat
# 64933                 0.0    Democrat
#
# [62714 rows x 12 columns]

# %%
# Export data with electoral vote to MongoDB
electiondb = client.election_db
collection = electiondb.electoral_data
data_dict = db_electoralVote.to_dict("records")
collection.insert_many(data_dict)

# %%
#electiondb.electoral_data.drop()
